# %% [markdown]
# # Pre-Processing Data to make to ready for analysis

# %%
import numpy as np
import pandas as pd
import os , sys , glob

# %%
# The environmet variable should be set at a system level rather than in code. Setting it now, as python is not picking it up.
# HAVE A CONFIGURATION FILE TO PICK UP THESE VALUES. WE DO CONFIGURATION FILES GET STORED. 
# ARE JUPYTER NOTEBOOKS DEPLOYED IN PRODUCTION OR CONVERTED TO PYTHON COMPILD FILES

#os.environ['DSX_PROJECT_DIR'] = "C:\\Project\\Data\\raw"
os.environ['PROJECT_DIR'] = "C:\\Users\\581686284\\PycharmProjects\\Automated_Ticket_Management\\"

# Getting the list of file in the directory

apps_files = glob.glob(os.environ['PROJECT_DIR'] +  "rawdata\\sm9\\apps\\*.csv")
windows_files = glob.glob(os.environ['PROJECT_DIR'] +  "rawdata\\sm9\\windows\\*.csv")

# %%
#%%timeit

# Reading all apps files . TO-DO : We're getting a warning that we need to handle. 
# Using concat takes 1.78 s ± 39.3 ms per loop , compared to append which takes 2.92 s ± 55.2 ms per loop. Hence, using concat
sm9_columns = ['Number','Assigned Dept','Assigned to','RBC Line Item Title','RBCMMPRITM','Submit Date','Close Date']
apps_df = [ pd.read_csv(app_file , encoding='latin-1' , usecols=sm9_columns ) for app_file in apps_files ]
apps_data = pd.concat(apps_df)
apps_data.head()

# apps_data = pd.DataFrame()
# for app_file in apps_files:
#     df = pd.read_csv(app_file , encoding='latin-1')
#     #apps_data = pd.concat([apps_data,df])
#     apps_data = apps_data.append(df,ignore_index=True)
# apps_data.loc[apps_data['RBCMMPRITM'] == 'RITM1095465']

# Number of tickets in apps data that have a value for RITM number
#apps_data.loc[~apps_data['RBCMMPRITM'].isnull()]
# Out:
#           Number Assigned to        Submit Date RBCMMPRITM  \
# 0  Q01654864-001   535506877    2005/01/17 6:51        NaN
# 1  Q01655290-001   310294822    2005/01/17 7:45        NaN
# 2  Q02211785-001   631444387  01/26/18 08:00:22        NaN
# 3  Q02244759-001   180190019    2002/09/18 9:32        NaN
# 4  Q02264742-001   324653500  02/16/18 21:15:44        NaN
#
#                    Assigned Dept         Close Date  \
# 0  EAA_APPLICATION SERVICES_IMPL   2004/02/18 11:47
# 1  EAA_APPLICATION SERVICES_IMPL   2004/02/18 13:54
# 2  EAA_APPLICATION SERVICES_IMPL  04/16/18 10:37:01
# 3  EAA_APPLICATION SERVICES_IMPL  04/17/18 09:58:56
# 4  EAA_APPLICATION SERVICES_IMPL   2004/02/18 19:37
#
#                                  RBC Line Item Title
# 0  A termination request has recently been submit...
# 1  A termination request has recently been submit...
# 2    04/14 - RBCIS term Frédéric ERBETTI - 523335040
# 3  04/15 PD  RBCIS - BEDFORD - EXIT Arnaud COURTO...
# 4                          ESAM HR TERMINATION - SM9

# %% [markdown]
# # Cleaning Data
#
# 1. We want to consider only Applications & Windows tickets.
# 2. We don't want to consider tickets where ticket has not been assigned to an analyst ( nan, Internal ). Convert Analyst Id to int to remove .0 (float).
# 3. We want to remove columns that have only NaN values.
#
#
# 5. OPEN QUESTION : HOW TO FIND LINE ITEM OF TICKETS IN SM9 WHICH HAVE NO RITM ?
#
# 6.

# %% [markdown]
# # Cleaning Apps Data from SM9

# %%
# Give me all tickets where RITM is null 

# apps_tickets_no_RITM = apps_data.loc[apps_data['RBCMMPRITM'].isnull()]
# apps_tickets_no_RITM.to_csv(path_or_buf= os.environ['PROJECT_DIR'] + "\\temp\\apps_tickets_no_RITM.csv" , encoding="Latin-1" , index = False)

# Give me all tickets where RITM is null , but Assigned To isn't 

# Give me all tickets where RITM is null 
#apps_data.columns
apps_tickets_no_RITM_but_assigned = apps_data.loc[apps_data['RBCMMPRITM'].isnull() & ~apps_data['Assigned to'].isnull()]
#len(apps_tickets_no_RITM_but_assigned)
#25744
#apps_tickets_no_RITM.to_csv(path_or_buf= os.environ['PROJECT_DIR'] + "\\temp\\apps_tickets_no_RITM.csv" , encoding="Latin-1" , index = False)
#len(apps_data)
#128080
#apps_data['Assigned Dept'].value_counts()
# Out:
# 128080

# %%
apps_data = apps_data.loc[apps_data['Assigned Dept'] == 'EAA_APPLICATION SERVICES_IMPL']
len(apps_data)
#106136
#apps_data.head()
# def object_to_int(x):
#     try:
#         return round(int(x))
#     except ValueError:
#         return None
    
# Converts objects to int (upcasted to float) & set None for those that can't be converted (NaN , Internal)
# apps_data['Assigned to'] = apps_data['Assigned to'].apply(object_to_int)

# apps_data.head()

# Remove those tickets that don't have Analyst linked to it. Noise. 
apps_data = apps_data[pd.notnull(apps_data['Assigned to'])]
#len(apps_data)
#104606
# Convert from float to int. All tickets that are assigned are now ints. Int are faster to process , is primitive, so takes 
# less memory

#apps_data['Assigned to'] = pd.to_numeric(apps_data['Assigned to'])

# Drop all columns having only NaN values (All unamed columns are filtered out)

#apps_data.dropna(axis=1, how='all' , inplace=True)



apps_data.head()
#apps_data.loc[apps_data['Assigned to'].isnull()]
# Out:
#           Number Assigned to        Submit Date RBCMMPRITM  \
# 0  Q01654864-001   535506877    2005/01/17 6:51        NaN
# 1  Q01655290-001   310294822    2005/01/17 7:45        NaN
# 2  Q02211785-001   631444387  01/26/18 08:00:22        NaN
# 3  Q02244759-001   180190019    2002/09/18 9:32        NaN
# 4  Q02264742-001   324653500  02/16/18 21:15:44        NaN
#
#                    Assigned Dept         Close Date  \
# 0  EAA_APPLICATION SERVICES_IMPL   2004/02/18 11:47
# 1  EAA_APPLICATION SERVICES_IMPL   2004/02/18 13:54
# 2  EAA_APPLICATION SERVICES_IMPL  04/16/18 10:37:01
# 3  EAA_APPLICATION SERVICES_IMPL  04/17/18 09:58:56
# 4  EAA_APPLICATION SERVICES_IMPL   2004/02/18 19:37
#
#                                  RBC Line Item Title
# 0  A termination request has recently been submit...
# 1  A termination request has recently been submit...
# 2    04/14 - RBCIS term Frédéric ERBETTI - 523335040
# 3  04/15 PD  RBCIS - BEDFORD - EXIT Arnaud COURTO...
# 4                          ESAM HR TERMINATION - SM9

# %% [markdown]
# # Cleaning Windows Data from SM9

# %%
#%%timeit

# Using concat takes 5.39 s ± 340 ms per loop , compared to append which takes 6.69 s ± 375 ms per loop. Hence, using concat

windows_df = [ pd.read_csv(windows_file , encoding='latin-1' , usecols=sm9_columns) for windows_file in windows_files ]
windows_data = pd.concat(windows_df)
windows_data.head()

# windows_data = pd.DataFrame()
# for windows_file in windows_files:
#     df = pd.read_csv(windows_file , encoding='latin-1')
#     #windows_data = pd.concat([windows_data,df])
#     windows_data = windows_data.append(df,ignore_index=True)
# windows_data
# Out:
#           Number Assigned to        Submit Date RBCMMPRITM  \
# 0  Q01370983-001         NaN  11/29/16 05:44:47        NaN
# 1  Q01482939-001   956519110    2002/01/17 6:52        NaN
# 2  Q01497296-001         NaN   2002/07/17 22:12        NaN
# 3  Q01504697-001         NaN    2002/11/17 0:01        NaN
# 4  Q01510173-001         NaN  02/14/17 22:08:31        NaN
#
#                Assigned Dept         Close Date  \
# 0  EAA_WINDOWS SERVICES_IMPL  04/21/17 03:10:36
# 1  EAA_WINDOWS SERVICES_IMPL    2004/03/17 7:38
# 2  EAA_WINDOWS SERVICES_IMPL  04/26/17 03:07:50
# 3  EAA_WINDOWS SERVICES_IMPL  04/26/17 03:07:55
# 4  EAA_WINDOWS SERVICES_IMPL  04/26/17 03:08:00
#
#                                  RBC Line Item Title
# 0  An access review has recently been completed b...
# 1  04/02 - PD - RBCIS - BEDFORD - termination - F...
# 2  An access review has recently been completed b...
# 3  An access review has recently been completed b...
# 4  An access review has recently been completed b...

# %%
# Give me all tickets where RITM is null 

# win_tickets_no_RITM = windows_data.loc[windows_data['RBCMMPRITM'].isnull()]
# win_tickets_no_RITM.to_csv(path_or_buf= os.environ['PROJECT_DIR'] + "\\temp\\win_tickets_no_RITM.csv" , encoding="Latin-1" , index = False)

# Give me all tickets where RITM is null , but Assigned To isn't 

# Give me all tickets where RITM is null 
#apps_data.columns
# win_tickets_no_RITM_but_assigned = windows_data.loc[windows_data['RBCMMPRITM'].isnull() & ~windows_data['Assigned to'].isnull()]
# len(win_tickets_no_RITM_but_assigned)
# #win_tickets_no_RITM_but_assigned.to_csv(path_or_buf= os.environ['PROJECT_DIR'] + "\\temp\\win_tickets_no_RITM_but_assigned.csv" , encoding="Latin-1" , index = False)
# len(windows_data)
#windows_data['Assigned Dept'].value_counts()
len(windows_data)
# Out:
# 128969

# %%
windows_data = windows_data.loc[windows_data['Assigned Dept'] == 'EAA_WINDOWS SERVICES_IMPL']
#len(windows_data)
# def object_to_int(x):
#     try:
#         return round(int(x))
#     except ValueError:
#         return None
    
# # Converts objects to int (upcasted to float) & set None for those that can't be converted (NaN , Internal)
# windows_data['Assigned to'] = windows_data['Assigned to'].apply(object_to_int)

# Remove those tickets that don't have Analyst linked to it. Noise. 
windows_data = windows_data[pd.notnull(windows_data['Assigned to'])]

# Convert from float to int. All tickets that are assigned are now ints. Int are faster to process , is primitive, so takes 
# less memory

# windows_data['Assigned to'] = pd.to_numeric(windows_data['Assigned to'])

# # Drop all columns having only NaN values (All unamed columns are filtered out)

# windows_data.dropna(axis=1, how='all' , inplace=True)

windows_data.head()
# Out:
#            Number Assigned to        Submit Date   RBCMMPRITM  \
# 1   Q01482939-001   956519110    2002/01/17 6:52          NaN
# 6   Q01525233-001   315467852  02/22/17 21:32:23  RITM0607195
# 8   Q01528761-001   936531946  02/24/17 09:28:36  RITM0612543
# 9   Q01529272-001   631444387  02/24/17 11:45:10  RITM0613254
# 10  Q00975425-003   631444387   2003/02/17 10:52          NaN
#
#                 Assigned Dept        Close Date  \
# 1   EAA_WINDOWS SERVICES_IMPL   2004/03/17 7:38
# 6   EAA_WINDOWS SERVICES_IMPL  2004/05/17 11:11
# 8   EAA_WINDOWS SERVICES_IMPL  2004/04/17 12:32
# 9   EAA_WINDOWS SERVICES_IMPL   2004/07/17 9:11
# 10  EAA_WINDOWS SERVICES_IMPL  2004/06/17 11:15
#
#                                   RBC Line Item Title
# 1   04/02 - PD - RBCIS - BEDFORD - termination - F...
# 6   3/4/17 - PD - EOD Grant Temporary Mailbox Acce...
# 8   04/04 - PD - revoke AGX and H drive. Remove al...
# 9                 04/07 - PD - Remove all User Access
# 10  03/?? - PO - RBCIS - BEDFORD - FAS/CAB Manager...

# %%
#%timeit
sm9_data = pd.concat([apps_data , windows_data])
sm9_data.to_csv(path_or_buf= os.environ['PROJECT_DIR'] + "\\datasets\\sm9.csv" , encoding="Latin-1" , index = False)

## NOTE : WHEN YOU LOAD SM9_DATA FROM CSV YOU NEED TO CONVERT THE ASSIGNED TO COLUMN TO INTEGER INSTEAD OF FLOAT.

# %%
# test_sm9_data = pd.read_csv(os.environ['PROJECT_DIR'] + "\\datasets\\sm9.csv" , encoding="Latin-1")
# test_sm9_data.head()

# Converts objects to int (upcasted to float) & set None for those that can't be converted (NaN , Internal)
# test_sm9_data['Assigned to'] = test_sm9_data['Assigned to'].apply(object_to_int)

# test_sm9_data['Assigned to'] = pd.to_numeric(test_sm9_data['Assigned to'])
sm9_data.head()
sm9_data.info()

len(sm9_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233575 entries, 0 to 11149
# Data columns (total 7 columns):
# Number                 233575 non-null object
# Assigned to            233575 non-null object
# Submit Date            233575 non-null object
# RBCMMPRITM             200114 non-null object
# Assigned Dept          233575 non-null object
# Close Date             233575 non-null object
# RBC Line Item Title    233569 non-null object
# dtypes: object(7)
# memory usage: 14.3+ MB
# 233575

# %%
# len(sm9_data['RBCMMPRITM'].unique())

# sm9_data['RBCMMPRITM'].value_counts()

sm9_data.head()
#233575

# Tickets that have been assigned, but don't have an RITM. These are tickets created from systems other than Service Now.
# sm9_data_no_RITM_but_assigned = sm9_data.loc[~sm9_data['Assigned to'].isnull() & sm9_data['RBCMMPRITM'].isnull()]
# len(sm9_data_no_RITM_but_assigned)
# 33461

# Tickets that have an RITM & have been assigned 
# sm9_data_RITM_and_assigned = sm9_data.loc[~sm9_data['Assigned to'].isnull() & ~sm9_data['RBCMMPRITM'].isnull()]
# len(sm9_data_RITM_and_assigned)
# 200114

sm9_data.rename(columns={"Assigned Dept" : "Assigned_Dept" , "Assigned to" : "Assigned_To" , "RBC Line Item Title" : "RBC_Line_Item_Title" ,'RBCMMPRITM' : 'RITM_Number'  } , inplace= True)
sm9_data.info()
sm9_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233575 entries, 0 to 11149
# Data columns (total 7 columns):
# Number                 233575 non-null object
# Assigned_To            233575 non-null object
# Submit Date            233575 non-null object
# RITM_Number            200114 non-null object
# Assigned_Dept          233575 non-null object
# Close Date             233575 non-null object
# RBC_Line_Item_Title    233569 non-null object
# dtypes: object(7)
# memory usage: 14.3+ MB
#           Number Assigned_To        Submit Date RITM_Number  \
# 0  Q01654864-001   535506877    2005/01/17 6:51         NaN
# 1  Q01655290-001   310294822    2005/01/17 7:45         NaN
# 2  Q02211785-001   631444387  01/26/18 08:00:22         NaN
# 3  Q02244759-001   180190019    2002/09/18 9:32         NaN
# 4  Q02264742-001   324653500  02/16/18 21:15:44         NaN
#
#                    Assigned_Dept         Close Date  \
# 0  EAA_APPLICATION SERVICES_IMPL   2004/02/18 11:47
# 1  EAA_APPLICATION SERVICES_IMPL   2004/02/18 13:54
# 2  EAA_APPLICATION SERVICES_IMPL  04/16/18 10:37:01
# 3  EAA_APPLICATION SERVICES_IMPL  04/17/18 09:58:56
# 4  EAA_APPLICATION SERVICES_IMPL   2004/02/18 19:37
#
#                                  RBC_Line_Item_Title
# 0  A termination request has recently been submit...
# 1  A termination request has recently been submit...
# 2    04/14 - RBCIS term Frédéric ERBETTI - 523335040
# 3  04/15 PD  RBCIS - BEDFORD - EXIT Arnaud COURTO...
# 4                          ESAM HR TERMINATION - SM9

# %%
#Get all tickets which has the same RITM Number. Analyze them

#sm9_data.groupby('RBCMMPRITM').value_counts()
#sm9_data['RBCMMPRITM'].value_counts().head()

# Get me all tickets where RITM is null 
# sm9_ritm_is_null = sm9_data.loc[sm9_data['RITM_Number'].isnull()]
# sm9_ritm_is_null.to_csv(path_or_buf= os.environ['PROJECT_DIR'] + "\\temp\\sm9_ritm_is_null.csv" , encoding="Latin-1" , index = False)
len(sm9_data.loc[sm9_data['RITM_Number'].isnull()])
# Out:
# 33461

# %%
sm9_data_rbc_line_item_title_not_null = sm9_data.loc[~sm9_data['RBC_Line_Item_Title'].isnull()]
sm9_data_rbc_line_item_title_not_null.loc[sm9_data_rbc_line_item_title_not_null['RBC_Line_Item_Title'].str.contains('A termination request has recently been submit')]
# Out:
#               Number Assigned_To        Submit Date RITM_Number  \
# 0      Q01654864-001   535506877    2005/01/17 6:51         NaN
# 1      Q01655290-001   310294822    2005/01/17 7:45         NaN
# 39     Q02330484-001   310294822  03/19/18 06:37:50         NaN
# 123    Q02346632-002   191458827  03/27/18 11:31:38         NaN
# 164    Q02351858-001   310294822  03/26/18 21:12:21         NaN
# 261    Q01725202-003   329808695   2004/03/18 12:38         NaN
# 262    Q01725202-004   329808695   2004/03/18 12:38         NaN
# 312    Q02357469-001   319749875  03/29/18 07:07:31         NaN
# 373    Q02358437-001   776883118  03/29/18 12:07:41         NaN
# 478    Q02359846-001   698544350  03/30/18 06:06:39         NaN
# 479    Q02359864-001   776883118  03/30/18 06:08:06         NaN
# 545    Q02360369-001   776883118    2004/02/18 6:05         NaN
# 546    Q02360378-001   776883118    2004/02/18 6:06         NaN
# 563    Q02360495-001   328874185    2004/02/18 6:11         NaN
# 564    Q02360506-001   318215316    2004/02/18 6:11         NaN
# 565    Q02360598-001   318215316    2004/02/18 6:15         NaN
# 566    Q02360614-001   328874185    2004/02/18 6:15         NaN
# 5482       EAA_WINDOWS SERVICES_IMPL  10/19/17 08:39:03
# 5595       EAA_WINDOWS SERVICES_IMPL  10/19/17 08:40:47
# 5596       EAA_WINDOWS SERVICES_IMPL  10/19/17 08:42:39
# 5597       EAA_WINDOWS SERVICES_IMPL  10/19/17 08:43:38
# 7965       EAA_WINDOWS SERVICES_IMPL  10/23/17 12:38:10
# 0          EAA_WINDOWS SERVICES_IMPL   2009/07/17 16:37
# 1          EAA_WINDOWS SERVICES_IMPL  09/20/17 16:42:08
# 3          EAA_WINDOWS SERVICES_IMPL  09/20/17 16:38:11
# 2751       EAA_WINDOWS SERVICES_IMPL  09/13/17 12:12:38
# 4232       EAA_WINDOWS SERVICES_IMPL  09/13/17 12:13:02
#
#                                      RBC_Line_Item_Title
# 0      A termination request has recently been submit...
# 1      A termination request has recently been submit...
# 39     A termination request has recently been submit...
# 123    A termination request has recently been submit...
# 164    A termination request has recently been submit...
# 261    A termination request has recently been submit...
# 262    A termination request has recently been submit...
# 312    A termination request has recently been submit...
# 373    A termination request has recently been submit...
# 478    A termination request has recently been submit...
# 479    A termination request has recently been submit...
# 545    A termination request has recently been submit...
# 546    A termination request has recently been submit...
# 563    A termination request has recently been submit...
# 564    A termination request has recently been submit...
# 565    A termination request has recently been submit...
# 566    A termination request has recently been submit...
# 567    A termination request has recently been submit...
# 568    A termination request has recently been submit...
# 569    A termination request has recently been submit...
# 570    A termination request has recently been submit...
# 571    A termination request has recently been submit...
# 572    A termination request has recently been submit...
# 573    RBCIS - BEDFORD A termination request has rece...
# 574    A termination request has recently been submit...
# 575    A termination request has recently been submit...
# 576    A termination request has recently been submit...
# 577    A termination request has recently been submit...
# 578    A termination request has recently been submit...
# 579    A termination request has recently been submit...
# ...                                                  ...
# 11489  A termination request has recently been submit...
# 13139  A termination request has recently been submit...
# 17950  A termination request has recently been submit...
# 17952  A termination request has recently been submit...
# 17955  A termination request has recently been submit...
# 0      A termination request has recently been submit...
# 1      A termination request has recently been submit...
# 6      A termination request has recently been submit...
# 9      A termination request has recently been submit...
# 2      Please read update.  A termination request has...
# 3      A termination request has recently been submit...
# 8      A termination request has recently been submit...
# 64     A termination request has recently been submit...
# 1349   A termination request has recently been submit...
# 4241   A termination request has recently been submit...
# 4245   RBCIS BEDFORD A termination request has recent...
# 4388   A termination request has recently been submit...
# 4389   A termination request has recently been submit...
# 5228   A termination request has recently been submit...
# 5380   A termination request has recently been submit...
# 5482   A termination request has recently been submit...
# 5595   A termination request has recently been submit...
# 5596   A termination request has recently been submit...
# 5597   A termination request has recently been submit...
# 7965   RBCIS BEDFORD  A termination request has recen...
# 0      A termination request has recently been submit...
# 1      A termination request has recently been submit...
# 3      A termination request has recently been submit...
# 2751   RBCIS BEDFORD  A termination request has recen...
# 4232   RBCIS BEDFORD A termination request has recent...
#
# [3524 rows x 7 columns]

# %%
sm9_data_rbc_line_item_title_not_null.loc[sm9_data_rbc_line_item_title_not_null['RBC_Line_Item_Title'].str.contains('Access Manager manual termination request') & sm9_data_rbc_line_item_title_not_null['RITM_Number'].isnull() ]
EAA_WINDOWS SERVICES_IMPL  09/21/17 12:28:19
# 8802      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:37:13
# 8804      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:28:36
# 8805      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:33:31
# 8806      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:28:52
# 8903      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:29:07
# 8905      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:33:47
# 8906      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:29:21
# 8907      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:38:59
# 8914      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:29:43
# 8915      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:34:04
# 8916      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:29:58
# 8934      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:35:31
# 8937      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:37:31
# 8938      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:35:50
# 8950      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:39:21
# 8954      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:37:45
# 8960      EAA_WINDOWS SERVICES_IMPL  09/28/17 10:14:17
# 8967      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:36:20
# 8969      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:36:33
# 8974      EAA_WINDOWS SERVICES_IMPL  09/28/17 10:14:00
# 8985      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:30:14
# 8991      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:36:05
# 8993      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:17:33
# 8996      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:30:30
# 8997      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:35:17
# 9004      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:39:48
# 9014      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:30:46
# 9053      EAA_WINDOWS SERVICES_IMPL  09/21/17 12:38:02
# 9060      EAA_WINDOWS SERVICES_IMPL  09/28/17 10:13:40
#
#                                     RBC_Line_Item_Title
# 1382  Access Manager manual termination request subm...
# 3708  cRTP Check last update Access Manager manual t...
# 3709  Access Manager manual termination request subm...
# 4638  RTP - AACG - Access Manager manual termination...
# 4639  RTP AACG - Access Manager manual termination r...
# 74    RBCIS - BEDFORD Access Manager manual terminat...
# 75    RBCIS - BEDFORD Access Manager manual terminat...
# 76    RBCIS - BEDFORD Access Manager manual terminat...
# 80    10/26 - PC Access Manager manual termination r...
# 103   Access Manager manual termination request subm...
# 105   Access Manager manual termination request subm...
# 106   Access Manager manual termination request subm...
# 4469  RBCIS - BEDFORD Access Manager manual terminat...
# 4470  RBCIS - BEDFORD Access Manager manual terminat...
# 4533  Access Manager manual termination request subm...
# 4731  Access Manager manual termination request subm...
# 4771  Access Manager manual termination request subm...
# 4773  Access Manager manual termination request subm...
# 4774  Access Manager manual termination request subm...
# 4775  Access Manager manual termination request subm...
# 4777  Access Manager manual termination request subm...
# 4817  Access Manager manual termination request subm...
# 4836  Access Manager manual termination request subm...
# 4837  Access Manager manual termination request subm...
# 4936  Access Manager manual termination request subm...
# 4965  Access Manager manual termination request subm...
# 4971  Access Manager manual termination request subm...
# 4995  Access Manager manual termination request subm...
# 4999  Access Manager manual termination request subm...
# 5020  Access Manager manual termination request subm...
# ...                                                 ...
# 8799  Access Manager manual termination request subm...
# 8802  Access Manager manual termination request subm...
# 8804  Access Manager manual termination request subm...
# 8805  Access Manager manual termination request subm...
# 8806  Access Manager manual termination request subm...
# 8903  Access Manager manual termination request subm...
# 8905  Access Manager manual termination request subm...
# 8906  Access Manager manual termination request subm...
# 8907  Access Manager manual termination request subm...
# 8914  Access Manager manual termination request subm...
# 8915  Access Manager manual termination request subm...
# 8916  Access Manager manual termination request subm...
# 8934  Access Manager manual termination request subm...
# 8937  Access Manager manual termination request subm...
# 8938  Access Manager manual termination request subm...
# 8950  Access Manager manual termination request subm...
# 8954  Access Manager manual termination request subm...
# 8960  Access Manager manual termination request subm...
# 8967  Access Manager manual termination request subm...
# 8969  Access Manager manual termination request subm...
# 8974  Access Manager manual termination request subm...
# 8985  Access Manager manual termination request subm...
# 8991  Access Manager manual termination request subm...
# 8993  Access Manager manual termination request subm...
# 8996  Access Manager manual termination request subm...
# 8997  Access Manager manual termination request subm...
# 9004  Access Manager manual termination request subm...
# 9014  Access Manager manual termination request subm...
# 9053  Access Manager manual termination request subm...
# 9060  Access Manager manual termination request subm...
#
# [180 rows x 7 columns]

# %%
#sm9_data.loc[sm9_data['RBCMMPRITM'] == 'RITM1095465']

sm9_data['RBC_Line_Item_Title'].loc[sm9_data['Number'] == 'Q02360722-001']
# Out:
# 571    A termination request has recently been submit...
# Name: RBC_Line_Item_Title, dtype: object

# %%
# Renaming columns as having spaces between columns in not a good practice. 


#sm9_data.rename(columns={"Assigned Dept" : "Assigned_Dept" , "Assigned to" : "Assigned_To" , "Close Date" : "Close_Date", "RBC Line Item Title" : "RBC_Line_Item_Title" , "Rbc Description" : "Rbc_Description" , "Submit Date" : "Submit_Date"  } , inplace= True)


# print(len(sm9_data))
# print(len(sm9_data['Number'].unique().tolist()))
#sm9_data.head()

#sm9_data.groupby(['Assigned_Dept','Assigned_To']).groups['EAA_WINDOWS SERVICES_IMPL']

#temp = sm9_data.groupby(['Assigned_Dept','Assigned_To'])['Assigned_To'].count().reset_index(name='count').sort_values(['count'], ascending=False)

# grouped = sm9_data.groupby(['Assigned_Dept','Assigned_To'], sort=False).count()
# grouped.sort_index(ascending=True)
# grouped



#sm9_data.groupby(['Assigned_Dept','Assigned_To'])['Assigned_To'].count()



#sm9_data.groupby(['Assigned_Dept','Assigned_To'])['Assigned_To'].count()

#sm9_data.sort_values(['Assigned_Dept','Assigned_To'],ascending=False).groupby(['Assigned_Dept','Assigned_To']).head(10)
#sm9_data['count'] = sm9_data.groupby(['Assigned_Dept','Assigned_To']).count()

#sm9_data
#grouped.keys()
#grouped.sort_values(['Assigned_Dept','Assigned_To'], ascending=False)

#temp.groupby(['Assigned_Dept','Assigned_To']).count()   

#sm9_data.groupby(['Assigned_Dept','Assigned_To'])['Assigned_To'].count()

#sm9_data.groupby('Assigned_Dept')['Assigned_To']

#temp

#len(sm9_data)

# ARE THERE COMMON LINE ITEMS BETWEEN WINDOWS & APPLICATION TICKETS. 

#pd.pivot_table(sm9_data, index = ['Assigned_To'] , columns=['Assigned_Dept'])

# %% [markdown]
# # Cleaning Service Now Data

# %% [markdown]
# We're only concerned with tickets that have been assigned to analyst. Based on inputs from domain experts

# %%
import pandas as pd
import glob , os

#sn_columns = ['cat_item','u_assignment_group','opened_by.u_rbchrplatformdesc','opened_by.u_rbchrplatformcode','opened_by.u_rbcbufugudesc','opened_by.u_rbcbufugu']

sn_columns = ['Number','Item','Stage', 'State','Assignment Group']
sn_files = glob.glob(os.environ['PROJECT_DIR'] +  "rawdata\\sn\\*.csv")

#sn_df = [pd.read_csv(sn_file , encoding='latin-1') for sn_file in sn_files]
sn_df = [pd.read_csv(sn_file , encoding='latin-1', usecols=sn_columns) for sn_file in sn_files]

sn_data = pd.concat(sn_df)

# sn_data = pd.read_csv(os.environ['PROJECT_DIR']+'rawdata\\sn\\*.csv' , encoding='latin-1' , 
#                       usecols= sn_columns )

#Filter Service Now data to contain only Windows & Application Services ticket

#sn_data['u_assignment_group'].value_counts()

sn_win_app_data = sn_data.loc[sn_data['Assignment Group'].isin(['EAA_WINDOWS SERVICES_IMPL' , 'EAA_APPLICATION SERVICES_IMPL'])]
#sn_win_app_data['u_assignment_group'].unique().tolist()

sn_win_app_data.rename(inplace = True , columns={'Number' : 'RITM_Number' , 'Assignment Group' : 'Assigned_Dept'})

#sn_win_app_data.groupby('cat_item')['u_assignment_group'].first() 
#len(sn_win_app_data)
sn_win_app_data = sn_win_app_data.loc[sn_win_app_data['Stage'].isin(['Completed','Fulfillment'])]
#len(sn_data)
#41930
#sn_data['State'].value_counts()
len(sn_win_app_data)
# sn_data['Stage'][sn_data['State'] != 'Closed Complete']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
# 41930

# %%
sn_win_app_data['Stage'].value_counts()

#len(sn_win_app_data['RITM_Number'].unique())
# Out:
# Completed      38588
# Fulfillment     3342
# Name: Stage, dtype: int64

# %%
#sn_win_app_data.loc[sn_win_app_data['RITM_Number'] == 'RITM1095465']
#RITM1757155
sn_data = sn_win_app_data[['RITM_Number','Assigned_Dept','Item']]
sn_data.shape
#len(sn_ritm)
# Out:
# (41930, 3)

# %%
sn_win_app_data['State'].value_counts()
# Out:
# Closed Complete      41601
# Work in Progress       278
# Closed Incomplete       28
# Pending                 21
# Open                     2
# Name: State, dtype: int64

# %%
# len(sm9_data.loc[sm9_data['RBCMMPRITM'].isin(sn_ritm)])
# 22454

#sm9_data.loc[sm9_data['RBCMMPRITM'].isin(sn_ritm)].head()
#len(sm9_data.loc[sm9_data['RITM_Number'].isin(sn_ritm)])

#len(sm9_data.loc[sm9_data['RITM_Number'].isin(sn_ritm)])
sn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41930 entries, 0 to 18000
# Data columns (total 3 columns):
# RITM_Number      41930 non-null object
# Assigned_Dept    41930 non-null object
# Item             41930 non-null object
# dtypes: object(3)
# memory usage: 1.3+ MB

# %%
# df_1 = sm9_data.loc[sm9_data['RBCMMPRITM'].isin(sn_ritm)]
# len(df_1['RBCMMPRITM'].unique())

# len(sm9_data.loc[sm9_data['RBCMMPRITM'].isin(sn_ritm)])

# %%
# df_1['RBCMMPRITM'].value_counts()

# %%
# sm9_data.columns
#sm9_data.rename(columns = {'RBCMMPRITM' : 'RITM_Number'} , inplace = True)
#sm9_data.loc[sm9_data['RITM_Number'] == 'RITM0583284']
#sm9_data.loc[sm9_data['RITM_Number'] == 'RITM0642300']

# %%
#sn_win_app_data.loc[sn_win_app_data['RITM_Number'] == 'RITM0583284']
#sn_win_app_data.loc[sn_win_app_data['RITM_Number'] == 'RITM0642300']

# %%
# # Playing with Merging 

# import pandas as pd

# df1 = pd.DataFrame({'HPI':[80,85,88,85],
#                     'Int_rate':[2, 3, 2, 2],
#                     'US_GDP_Thousands':[50, 55, 65, 55]},
#                    index = [2001, 2002, 2003, 2004])

# df2 = pd.DataFrame({'HPI':[80,85,88,85],
#                     'Int_rate':[2, 3, 2, 2],
#                     'US_GDP_Thousands':[50, 55, 65, 55]},
#                    index = [2005, 2006, 2007, 2008])

# df3 = pd.DataFrame({'HPI':[80,85,88,85],
#                     'Unemployment':[7, 8, 9, 6],
#                     'Low_tier_HPI':[50, 52, 50, 53]},
#                    index = [2001, 2002, 2003, 2004])

# print(pd.merge(df1,df3, on='HPI'))

# %%
#sm9_data.head()

#sm9_data_1 = sm9_data[['Number','Rbc Description' , 'Assigned to','RITM_Number','Assigned Dept',]]
#sm9_data.columns

# %%
# sn_win_app_data.head()

# sn_win_app_data_1 = sn_win_app_data[['RITM_Number','Item','Assigned Dept']]
sn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41930 entries, 0 to 18000
# Data columns (total 3 columns):
# RITM_Number      41930 non-null object
# Assigned_Dept    41930 non-null object
# Item             41930 non-null object
# dtypes: object(3)
# memory usage: 1.3+ MB

# %%
sm9_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233575 entries, 0 to 11149
# Data columns (total 7 columns):
# Number                 233575 non-null object
# Assigned_To            233575 non-null object
# Submit Date            233575 non-null object
# RITM_Number            200114 non-null object
# Assigned_Dept          233575 non-null object
# Close Date             233575 non-null object
# RBC_Line_Item_Title    233569 non-null object
# dtypes: object(7)
# memory usage: 14.3+ MB

# %%
merged_data = pd.merge(sn_data,sm9_data, on='RITM_Number', how='outer')
#merged_data.loc[merged_data['RITM_Number'] == 'RITM0583284']
#merged_data.head()
len(merged_data)
#256328
#merged_data.head(10)

# merged_data.loc[merged_data['RITM_Number'].isnull()]
# 33461
# Out:
# 256328

# %%
# All tickets which are not assigned to an analyst 

# We need to ensure we don't consider tickets that are not present in SM9, since they are auto-resolved. Do thhis only after 
# you receive confirmation on email sent out to Nadia / Blake on 19th June 2018. 

merged_data_not_assigned = merged_data.loc[merged_data['Assigned_To'].isnull()]
merged_data_not_assigned['Item'].value_counts()
merged_data_not_assigned.to_csv(path_or_buf= os.environ['PROJECT_DIR'] + "\\temp\\merged_data_not_assigned.csv" , encoding="Latin-1" , index = False)
#len(merged_data_not_assigned)
#22753

# Tickets that are assigned to analyst 

# merged_data_assigned = merged_data.loc[~merged_data['Assigned_To'].isnull()]
# len(merged_data_assigned)
#233575

#merged_data_assigned['RITM_Number'].value_counts()

# %%
merged_data_assigned.loc[merged_data_assigned['RITM_Number'] == 'RITM0998292']
# Out:
#         RITM_Number Assigned_Dept_x Item         Number Assigned_To  \
# 200384  RITM0998292             NaN  NaN  Q01810656-001   322930777
# 200385  RITM0998292             NaN  NaN  Q01810666-001   322930777
# 200386  RITM0998292             NaN  NaN  Q01810692-001   322930777
# 200387  RITM0998292             NaN  NaN  Q01810699-001   322930777
# 200388  RITM0998292             NaN  NaN  Q01810704-001   322930777
# 200389  RITM0998292             NaN  NaN  Q01810707-001   322930777
# 200390  RITM0998292             NaN  NaN  Q01810713-001   322930777
# 200391  RITM0998292             NaN  NaN  Q01810715-001   322930777
# 200392  RITM0998292             NaN  NaN  Q01810719-001   322930777
# 200393  RITM0998292             NaN  NaN  Q01810742-001   322930777
# 200394  RITM0998292             NaN  NaN  Q01810744-001   322930777
# 200395  RITM0998292             NaN  NaN  Q01810746-001   322930777
# 200396  RITM0998292             NaN  NaN  Q01810760-001   322930777
#
#               Submit Date            Assigned_Dept_y         Close Date  \
# 200384  07/18/17 13:49:24  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:40:49
# 200385  07/18/17 13:50:46  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:42:24
# 200386  07/18/17 13:55:55  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:41:01
# 200387  07/18/17 13:57:17  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:42:59
# 200388  07/18/17 13:58:31  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:41:12
# 200389  07/18/17 13:59:40  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:42:36
# 200390  07/18/17 14:01:00  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:41:25
# 200391  07/18/17 14:02:11  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:43:56
# 200392  07/18/17 14:03:25  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:41:39
# 200393  07/18/17 14:06:28  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:42:46
# 200394  07/18/17 14:07:43  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:41:51
# 200395  07/18/17 14:07:49  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:43:10
# 200396  07/18/17 14:10:18  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:42:05
#
#                          RBC_Line_Item_Title
# 200384  Personal Mailbox Access - Add/Remove
# 200385  Personal Mailbox Access - Add/Remove
# 200386  Personal Mailbox Access - Add/Remove
# 200387  Personal Mailbox Access - Add/Remove
# 200388  Personal Mailbox Access - Add/Remove
# 200389  Personal Mailbox Access - Add/Remove
# 200390  Personal Mailbox Access - Add/Remove
# 200391  Personal Mailbox Access - Add/Remove
# 200392  Personal Mailbox Access - Add/Remove
# 200393  Personal Mailbox Access - Add/Remove
# 200394  Personal Mailbox Access - Add/Remove
# 200395  Personal Mailbox Access - Add/Remove
# 200396  Personal Mailbox Access - Add/Remove

# %%
# Give me all tickets / rows where no column has NaN 

#len(merged_data.dropna(axis=0 , how="any" ))
#22215

#merged_data.loc[merged_data.isnull().  ]

#len(merged_data)
#264095

merged_data.dropna(axis=0 , how="any")

# %%
# Analysis of ticket present in Service Now, but not in SM9. 
# NOTE : WE ARE YET TO HAVE SERVICE NOW DATA FOR 2018. 

sn_data.info()
sm9_data.loc[sm9_data['RITM_Number'] == 'RITM1095465']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41930 entries, 0 to 18000
# Data columns (total 3 columns):
# RITM_Number      41930 non-null object
# Assigned_Dept    41930 non-null object
# Item             41930 non-null object
# dtypes: object(3)
# memory usage: 1.3+ MB
#      Assigned_To  RITM_Number                  Assigned_Dept  \
# 8832   318215316  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 8833   318215316  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 8834   310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 8835   318215316  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 8836   318215316  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 28     310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 89     310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 90     310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 5009   310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 97     310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 98     310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 99     310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 100    543589881  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 101    310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 102    310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 172    310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 173    310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 183    310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 184    310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 4660   698544350  RITM1095465  EAA_APPLICATION SERVICES_IMPL
#
#                                     RBC_Line_Item_Title
# 8832                                   RTP - DFR (XDQ0)
# 8833                          RTP - ICI - IMPACT (XTT0)
# 8834                                RTP - IMatch (YWH0)
# 8835                                RTP - P&L NY (XZT0)
# 8836                            RTP - SLIM - MAH (XAU0)
# 28      RTP - SWIFT Messaging Platform - Clarity (VMD0)
# 89                                  RTP - IMatch (YWH0)
# 90         RTP - Counter-party credit risk - CCR (SIF0)
# 5009                               RTP -  IMatch (YWH0)
# 97                          RTP - ADP Gloss - TE (ZTX0)
# 98                            RTP - E-OPS/IRIS - (ZPV0)
# 99                              RTP - Smart Loan (WMM0)
# 100                      RTP - Yieldbroker Debts (WWF0)
# 101                     RTP - Workflow Atlas/NDF (ZPX0)
# 102                      RTP - Workflow-OpenLink (WOK0)
# 172   RTP - SunGard Apex fro Orain (SMB0) - Please u...
# 173                                RTP - DSPRIME (ZMI0)
# 183                      RTP - Workflow - London (ZNP0)
# 184                     RTP - Workflow - Toronto (YWQ0)
# 4660                          RTP - E-OPS/IRIS - (ZPV0)

# %%
# Get me data where 
merged_data_assigned_temp = merged_data_assigned.loc[~merged_data_assigned['Item'].isnull()]
merged_data_assigned_temp.loc[merged_data_assigned_temp['Item'].str.contains('Personal Mailbox Access')]
# Out:
#        RITM_Number            Assigned_Dept_x  \
# 59     RITM0507545  EAA_WINDOWS SERVICES_IMPL
# 245    RITM0508269  EAA_WINDOWS SERVICES_IMPL
# 402    RITM0508807  EAA_WINDOWS SERVICES_IMPL
# 432    RITM0508898  EAA_WINDOWS SERVICES_IMPL
# 517    RITM0509231  EAA_WINDOWS SERVICES_IMPL
# 605    RITM0509514  EAA_WINDOWS SERVICES_IMPL
# 798    RITM0510377  EAA_WINDOWS SERVICES_IMPL
# 871    RITM0510599  EAA_WINDOWS SERVICES_IMPL
# 1044   RITM0511167  EAA_WINDOWS SERVICES_IMPL
# 1065   RITM0511241  EAA_WINDOWS SERVICES_IMPL
# 1111   RITM0511415  EAA_WINDOWS SERVICES_IMPL
# 1126   RITM0511478  EAA_WINDOWS SERVICES_IMPL
# 1172   RITM0511642  EAA_WINDOWS SERVICES_IMPL
# 1309   RITM0512027  EAA_WINDOWS SERVICES_IMPL
# 1310   RITM0512027  EAA_WINDOWS SERVICES_IMPL
# 1311   RITM0512027  EAA_WINDOWS SERVICES_IMPL
# 1384   RITM0512348  EAA_WINDOWS SERVICES_IMPL
# 1849   RITM0513814  EAA_WINDOWS SERVICES_IMPL
# 2121   RITM0514670  EAA_WINDOWS SERVICES_IMPL
# 2142   RITM0514738  EAA_WINDOWS SERVICES_IMPL
# 2204   RITM0515024  EAA_WINDOWS SERVICES_IMPL
# 2302   RITM0515337  EAA_WINDOWS SERVICES_IMPL
# 2303   RITM0515339  EAA_WINDOWS SERVICES_IMPL
# 2364   RITM0515640  EAA_WINDOWS SERVICES_IMPL
# 2534   RITM0516218  EAA_WINDOWS SERVICES_IMPL
# 2563   RITM0516335  EAA_WINDOWS SERVICES_IMPL
# 2766   RITM0516976  EAA_WINDOWS SERVICES_IMPL
# 2842   RITM0517226  EAA_WINDOWS SERVICES_IMPL
# 3082   RITM0518067  EAA_WINDOWS SERVICES_IMPL
# 3390   RITM0519138  EAA_WINDOWS SERVICES_IMPL
# ...            ...                        ...
# 34265  RITM0635052  EAA_WINDOWS SERVICES_IMPL
# 34432  RITM0635565  EAA_WINDOWS SERVICES_IMPL
# 35448  RITM0639490  EAA_WINDOWS SERVICES_IMPL
# 35843  RITM0641160  EAA_WINDOWS SERVICES_IMPL
# 36126  RITM0642339  EAA_WINDOWS SERVICES_IMPL
# 36230  RITM0642912  EAA_WINDOWS SERVICES_IMPL
# 36307  RITM0643533  EAA_WINDOWS SERVICES_IMPL
# 37329  RITM0647806  EAA_WINDOWS SERVICES_IMPL
# 37477  RITM0648321  EAA_WINDOWS SERVICES_IMPL
# 37505  RITM0648449  EAA_WINDOWS SERVICES_IMPL
# 37573  RITM0648759  EAA_WINDOWS SERVICES_IMPL
# 37905  RITM0650348  EAA_WINDOWS SERVICES_IMPL
# 38531  RITM0653418  EAA_WINDOWS SERVICES_IMPL
# 38606  RITM0653613  EAA_WINDOWS SERVICES_IMPL
# 38878  RITM0654608  EAA_WINDOWS SERVICES_IMPL
# 39017  RITM0655444  EAA_WINDOWS SERVICES_IMPL
# 39223  RITM0656466  EAA_WINDOWS SERVICES_IMPL
# 39486  RITM0658038  EAA_WINDOWS SERVICES_IMPL
# 39898  RITM0660060  EAA_WINDOWS SERVICES_IMPL
# 40080  RITM0660721  EAA_WINDOWS SERVICES_IMPL
# 40344  RITM0662150  EAA_WINDOWS SERVICES_IMPL
# 40562  RITM0663170  EAA_WINDOWS SERVICES_IMPL
# 41190  RITM0666379  EAA_WINDOWS SERVICES_IMPL
# 41806  RITM0669906  EAA_WINDOWS SERVICES_IMPL
# 41908  RITM0670262  EAA_WINDOWS SERVICES_IMPL
# 42441  RITM0672852  EAA_WINDOWS SERVICES_IMPL
# 42609  RITM0673470  EAA_WINDOWS SERVICES_IMPL
# 43080  RITM0675904  EAA_WINDOWS SERVICES_IMPL
# 43629  RITM0678524  EAA_WINDOWS SERVICES_IMPL
# 44188  RITM0681337  EAA_WINDOWS SERVICES_IMPL
#
#                                        Item         Number Assigned_To  \
# 59     Personal Mailbox Access - Add/Remove  Q01424688-001   180626202
# 245    Personal Mailbox Access - Add/Remove  Q01464504-001   318801727
# 402    Personal Mailbox Access - Add/Remove  Q01426417-001   180190019
# 432    Personal Mailbox Access - Add/Remove  Q01426496-001   180190019
# 517    Personal Mailbox Access - Add/Remove  Q01426788-001   543598601
# 605    Personal Mailbox Access - Add/Remove  Q01427064-001   318801727
# 798    Personal Mailbox Access - Add/Remove  Q01428037-001   315467852
# 871    Personal Mailbox Access - Add/Remove  Q01433372-001   294555602
# 1044   Personal Mailbox Access - Add/Remove  Q01450192-001   315467852
# 1065   Personal Mailbox Access - Add/Remove  Q01428686-001   315467852
# 1111   Personal Mailbox Access - Add/Remove  Q01436258-001   180190019
# 1126   Personal Mailbox Access - Add/Remove  Q01451586-001   956519110
# 1172   Personal Mailbox Access - Add/Remove  Q01428972-001   315467852
# 1309   Personal Mailbox Access - Add/Remove  Q01429281-001   956519110
# 1310   Personal Mailbox Access - Add/Remove  Q01429281-002   956519110
# 1311   Personal Mailbox Access - Add/Remove  Q01429281-003   936531946
# 1384   Personal Mailbox Access - Add/Remove  Q01429559-001   315467852
# 1849   Personal Mailbox Access - Add/Remove  Q01435746-001   180626202
# 2121   Personal Mailbox Access - Add/Remove  Q01431944-001   956519110
# 2142   Personal Mailbox Access - Add/Remove  Q01432038-001   190899732
# 2204   Personal Mailbox Access - Add/Remove  Q01432467-001   180626202
# 2302   Personal Mailbox Access - Add/Remove  Q01434100-001   191918473
# 2303   Personal Mailbox Access - Add/Remove  Q01432546-001   191918473
# 2364   Personal Mailbox Access - Add/Remove  Q01433086-001   522079805
# 2534   Personal Mailbox Access - Add/Remove  Q01433769-001   322888413
# 2563   Personal Mailbox Access - Add/Remove  Q01451950-001   956519110
# 2766   Personal Mailbox Access - Add/Remove  Q01434566-001   180190019
# 2842   Personal Mailbox Access - Add/Remove  Q01434787-001   180190019
# 3082   Personal Mailbox Access - Add/Remove  Q01436346-001   180626202
# 3390   Personal Mailbox Access - Add/Remove  Q01437950-001   180626202
# ...                                     ...            ...         ...
# 34265  Personal Mailbox Access - Add/Remove  Q01547583-001   323159210
# 34432  Personal Mailbox Access - Add/Remove  Q01547571-001   323159210
# 35448  Personal Mailbox Access - Add/Remove  Q01556324-001   180626202
# 35843  Personal Mailbox Access - Add/Remove  Q01560977-001   180626202
# 36126  Personal Mailbox Access - Add/Remove  Q01555433-001   315467852
# 36230  Personal Mailbox Access - Add/Remove  Q01552740-001   315467852
# 36307  Personal Mailbox Access - Add/Remove  Q01552945-001   180626202
# 37329  Personal Mailbox Access - Add/Remove  Q01556028-001   296472020
# 37477  Personal Mailbox Access - Add/Remove  Q01558187-001   180626202
# 37505  Personal Mailbox Access - Add/Remove  Q01555894-001   535902738
# 37573  Personal Mailbox Access - Add/Remove  Q01556142-001   296472020
# 37905  Personal Mailbox Access - Add/Remove  Q01557720-001   180626202
# 38531  Personal Mailbox Access - Add/Remove  Q01562233-001   322888413
# 38606  Personal Mailbox Access - Add/Remove  Q01562436-001   322888413
# 38878  Personal Mailbox Access - Add/Remove  Q01563209-001   322888413
# 39017  Personal Mailbox Access - Add/Remove  Q01565259-001   322888413
# 39223  Personal Mailbox Access - Add/Remove  Q01564002-001   322888413
# 39486  Personal Mailbox Access - Add/Remove  Q01564871-001   322888413
# 39898  Personal Mailbox Access - Add/Remove  Q01565888-001   322888413
# 40080  Personal Mailbox Access - Add/Remove  Q01566200-001   322888413
# 40344  Personal Mailbox Access - Add/Remove  Q01567408-001   322888413
# 40562  Personal Mailbox Access - Add/Remove  Q01568070-001   322888413
# 41190  Personal Mailbox Access - Add/Remove  Q01570821-001   322888413
# 41806  Personal Mailbox Access - Add/Remove  Q01572412-001   322888413
# 41908  Personal Mailbox Access - Add/Remove  Q01572919-001   322888413
# 42441  Personal Mailbox Access - Add/Remove  Q01574841-001   322888413
# 42609  Personal Mailbox Access - Add/Remove  Q01575254-001   322888413
# 43080  Personal Mailbox Access - Add/Remove  Q01577147-001   322888413
# 43629  Personal Mailbox Access - Add/Remove  Q01578947-001   322888413
# 245                 Personal Mailbox Access - Add/Remove
# 402    2/3  ** See Updates ** 1/27  Personal Mailbox ...
# 432                 Personal Mailbox Access - Add/Remove
# 517                 Personal Mailbox Access - Add/Remove
# 605                 Personal Mailbox Access - Add/Remove
# 798                 Personal Mailbox Access - Add/Remove
# 871                 Personal Mailbox Access - Add/Remove
# 1044                Personal Mailbox Access - Add/Remove
# 1065                Personal Mailbox Access - Add/Remove
# 1111                Personal Mailbox Access - Add/Remove
# 1126                Personal Mailbox Access - Add/Remove
# 1172                Personal Mailbox Access - Add/Remove
# 1309           * ESC OOSLA -Please Merge AutoSab  record
# 1310   ** ESC - MERGE issue - Personal Mailbox Access...
# 1311   Jan 25 - just in case. Personal Mailbox Access...
# 1384                Personal Mailbox Access - Add/Remove
# 1849                Personal Mailbox Access - Add/Remove
# 2121        * ESC - Personal Mailbox Access - Add/Remove
# 2142   * ESC - Jan 11 - See updates - Personal Mailbo...
# 2204                Personal Mailbox Access - Add/Remove
# 2302   ** ESC  URGENT Personal Mailbox Access - Add/R...
# 2303   ESCALATION   ** ESC URGENT -Personal Mailbox A...
# 2364   * ESC - Jan 11 - See updates - Personal Mailbo...
# 2534   Remove all User Access    Personal Mailbox Acc...
# 2563                Personal Mailbox Access - Add/Remove
# 2766                Personal Mailbox Access - Add/Remove
# 2842                Personal Mailbox Access - Add/Remove
# 3082                Personal Mailbox Access - Add/Remove
# 3390                Personal Mailbox Access - Add/Remove
# ...                                                  ...
# 34265               Personal Mailbox Access - Add/Remove
# 34432  *ESC 03/09 - RUSH - Personal Mailbox Access - ...
# 35448               Personal Mailbox Access - Add/Remove
# 35843               Personal Mailbox Access - Add/Remove
# 36126              Temporary Mailbox Access - Add/Remove
# 36230               Personal Mailbox Access - Add/Remove
# 36307               Personal Mailbox Access - Add/Remove
# 37329               Personal Mailbox Access - Add/Remove
# 37477      03/22 PA Personal Mailbox Access - Add/Remove
# 37505  * ESC - Mar 14 - see updates - Personal Mailbo...
# 37573               Personal Mailbox Access - Add/Remove
# 37905  *ESC 03/13 - RUSH - Personal Mailbox Access - ...
# 38531               Personal Mailbox Access - Add/Remove
# 38606  03/20 - PT - Personal Mailbox Access - Add/Remove
# 38878  *ESC 03/20 - RUSH- Personal Mailbox Access - A...
# 39017               Personal Mailbox Access - Add/Remove
# 39223               Personal Mailbox Access - Add/Remove
# 39486               Personal Mailbox Access - Add/Remove
# 39898               Personal Mailbox Access - Add/Remove
# 40080               Personal Mailbox Access - Add/Remove
# 40344  03/20 - PT -*ESC See Updates - Personal Mailbo...
# 40562               Personal Mailbox Access - Add/Remove
# 41190               Personal Mailbox Access - Add/Remove
# 41806               Personal Mailbox Access - Add/Remove
# 41908               Personal Mailbox Access - Add/Remove
# 42441               Personal Mailbox Access - Add/Remove
# 42609               Personal Mailbox Access - Add/Remove
# 43080               Personal Mailbox Access - Add/Remove
# 43629               Personal Mailbox Access - Add/Remove
# 44188    *ESC* RUSH Personal Mailbox Access - Add/Remove
#
# [219 rows x 9 columns]
