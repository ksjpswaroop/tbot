# %% [markdown]
# # Pre-Processing Data to make to ready for analysis

# %%
import numpy as np
import pandas as pd
import os , sys , glob

# %%
# The environmet variable should be set at a system level rather than in code. Setting it now, as python is not picking it up.
# HAVE A CONFIGURATION FILE TO PICK UP THESE VALUES. WE DO CONFIGURATION FILES GET STORED. 
# ARE JUPYTER NOTEBOOKS DEPLOYED IN PRODUCTION OR CONVERTED TO PYTHON COMPILD FILES

#os.environ['DSX_PROJECT_DIR'] = "C:\\Project\\Data\\raw"
os.environ['PROJECT_DIR'] = "C:\\Users\\581686284\\PycharmProjects\\Automated_Ticket_Management\\"

# Getting the list of file in the directory

apps_files = glob.glob(os.environ['PROJECT_DIR'] +  "rawdata\\sm9\\apps\\*.csv")
windows_files = glob.glob(os.environ['PROJECT_DIR'] +  "rawdata\\sm9\\windows\\*.csv")

# %%
#%%timeit

# Reading all apps files . TO-DO : We're getting a warning that we need to handle. 
# Using concat takes 1.78 s ± 39.3 ms per loop , compared to append which takes 2.92 s ± 55.2 ms per loop. Hence, using concat
sm9_columns = ['Number','Assigned Dept','Assigned to','RBC Line Item Title','RBCMMPRITM','Rbc Description','Submit Date','Close Date']
apps_df = [ pd.read_csv(app_file , encoding='latin-1' , usecols=sm9_columns ) for app_file in apps_files ]
apps_data = pd.concat(apps_df)
apps_data.shape
# (128080, 8)

# apps_data = pd.DataFrame()
# for app_file in apps_files:
#     df = pd.read_csv(app_file , encoding='latin-1')
#     #apps_data = pd.concat([apps_data,df])
#     apps_data = apps_data.append(df,ignore_index=True)
# apps_data.loc[apps_data['RBCMMPRITM'] == 'RITM1095465']

# Number of tickets in apps data that have a value for RITM number
#apps_data.loc[~apps_data['RBCMMPRITM'].isnull()]
# Out:
# (128080, 8)

# %% [markdown]
# # Cleaning Data
#
# 1. We want to consider only Applications & Windows tickets.
# 2. We don't want to consider tickets where ticket has not been assigned to an analyst ( nan, Internal ). Convert Analyst Id to int to remove .0 (float).
# 3. We want to remove columns that have only NaN values.
#
#
# 5. OPEN QUESTION : HOW TO FIND LINE ITEM OF TICKETS IN SM9 WHICH HAVE NO RITM ?
#
# 6.

# %% [markdown]
# # Cleaning Apps Data from SM9

# %%
# Give me all tickets where RITM is null , but Assigned To isn't 

#apps_tickets_no_RITM = apps_data.loc[apps_data['RBCMMPRITM'].isnull() & ~apps_data['Assigned to'].isnull()]

#len(apps_tickets_no_RITM)
#25744
#apps_tickets_no_RITM.to_csv(path_or_buf= os.environ['PROJECT_DIR'] + "\\temp\\apps_tickets_no_RITM.csv" , encoding="Latin-1" , index = False)
#len(apps_data)
#128080
#apps_data['Assigned Dept'].value_counts()

# %%
apps_data = apps_data.loc[apps_data['Assigned Dept'] == 'EAA_APPLICATION SERVICES_IMPL']
len(apps_data)
#106136

# Remove those tickets that don't have Analyst linked to it. Noise. 
apps_data = apps_data[pd.notnull(apps_data['Assigned to'])]

#len(apps_data)
#104606

apps_data.shape
#apps_data.loc[apps_data['Assigned to'].isnull()]
# Out:
# (104606, 8)

# %% [markdown]
# # Cleaning Windows Data from SM9

# %%
#%%timeit

# Using concat takes 5.39 s ± 340 ms per loop , compared to append which takes 6.69 s ± 375 ms per loop. Hence, using concat

windows_df = [ pd.read_csv(windows_file , encoding='latin-1' , usecols=sm9_columns) for windows_file in windows_files ]
windows_data = pd.concat(windows_df)
#windows_data.shape
#(196426, 8)

# windows_data = pd.DataFrame()
# for windows_file in windows_files:
#     df = pd.read_csv(windows_file , encoding='latin-1')
#     #windows_data = pd.concat([windows_data,df])
#     windows_data = windows_data.append(df,ignore_index=True)
# windows_data
# Out:
# (196426, 8)

# %%
# Give me all tickets where RITM is null , but Assigned To isn't 

# Give me all tickets where RITM is null 
#win_tickets_no_RITM = windows_data.loc[windows_data['RBCMMPRITM'].isnull() & ~windows_data['Assigned to'].isnull()]
# len(win_tickets_no_RITM)
# 7989
#windows_data['Assigned Dept'].value_counts()
#len(windows_data)
# Out:
# 7989

# %%
windows_data = windows_data.loc[windows_data['Assigned Dept'] == 'EAA_WINDOWS SERVICES_IMPL']

# Remove those tickets that don't have Analyst linked to it. Noise. 
windows_data = windows_data[pd.notnull(windows_data['Assigned to'])]
windows_data.shape
# Out:
# (128969, 8)

# %%
#%timeit
sm9_data = pd.concat([apps_data , windows_data])
sm9_data.to_csv(path_or_buf= os.environ['PROJECT_DIR'] + "\\datasets\\sm9.csv" , encoding="Latin-1" , index = False)
sm9_data.shape

## NOTE : WHEN YOU LOAD SM9_DATA FROM CSV YOU NEED TO CONVERT THE ASSIGNED TO COLUMN TO INTEGER INSTEAD OF FLOAT.
# Out:
# (233575, 8)

# %%
# test_sm9_data = pd.read_csv(os.environ['PROJECT_DIR'] + "\\datasets\\sm9.csv" , encoding="Latin-1")
# test_sm9_data.head()

# Converts objects to int (upcasted to float) & set None for those that can't be converted (NaN , Internal)
# test_sm9_data['Assigned to'] = test_sm9_data['Assigned to'].apply(object_to_int)

# test_sm9_data['Assigned to'] = pd.to_numeric(test_sm9_data['Assigned to'])
sm9_data.head()
sm9_data.info()

len(sm9_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233575 entries, 0 to 11149
# Data columns (total 7 columns):
# Number                 233575 non-null object
# Assigned to            233575 non-null object
# Submit Date            233575 non-null object
# RBCMMPRITM             200114 non-null object
# Assigned Dept          233575 non-null object
# Close Date             233575 non-null object
# RBC Line Item Title    233569 non-null object
# dtypes: object(7)
# memory usage: 14.3+ MB
# 233575

# %%
# len(sm9_data['RBCMMPRITM'].unique())

# sm9_data['RBCMMPRITM'].value_counts()

sm9_data.head()
#233575

# Tickets that have been assigned, but don't have an RITM. These are tickets created from systems other than Service Now.
# sm9_data_no_RITM_but_assigned = sm9_data.loc[~sm9_data['Assigned to'].isnull() & sm9_data['RBCMMPRITM'].isnull()]
# len(sm9_data_no_RITM_but_assigned)
# 33461

# Tickets that have an RITM & have been assigned 
# sm9_data_RITM_and_assigned = sm9_data.loc[~sm9_data['Assigned to'].isnull() & ~sm9_data['RBCMMPRITM'].isnull()]
# len(sm9_data_RITM_and_assigned)
# 200114

sm9_data.rename(columns={"Assigned Dept" : "Assigned_Dept" , "Assigned to" : "Assigned_To" , "RBC Line Item Title" : "RBC_Line_Item_Title" ,'RBCMMPRITM' : 'RITM_Number' , 'Rbc Description' : 'RBC_Description' } , inplace= True)
sm9_data.info()
sm9_data.head()

# Separate SM9 data with & without RITM. RITM number helps us merge SM9 data with Service Now. The advantage of Service Now data 
# having a standardized Line Item Title. 

# For those not having a RITM, as tickets raised from systems outside Service Now. Their line item title is not standard. So, 
# when a new ticket comes in & doesn't have RITM number, we'll recommend based on similar tickets that have been resolved
# using document similarity

sm9_data_without_RITM = sm9_data.loc[sm9_data['RITM_Number'].isnull()]
sm9_data_with_RITM = sm9_data.loc[~sm9_data['RITM_Number'].isnull()]
sm9_data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233575 entries, 0 to 11149
# Data columns (total 8 columns):
# Number                 233575 non-null object
# RBC_Description        233567 non-null object
# Assigned_To            233575 non-null object
# Submit Date            233575 non-null object
# RITM_Number            200114 non-null object
# Assigned_Dept          233575 non-null object
# Close Date             233575 non-null object
# RBC_Line_Item_Title    233569 non-null object
# dtypes: object(8)
# memory usage: 16.0+ MB
# (233575, 8)

# %% [markdown]
# # Cleaning Service Now Data

# %% [markdown]
# We're only concerned with tickets that have been assigned to analyst. Based on inputs from domain experts

# %%
import pandas as pd
import glob , os

sn_files = glob.glob(os.environ['PROJECT_DIR'] +  "rawdata\\sn\\*.csv")

#sn_files
sn_df = [pd.read_csv(sn_file , encoding='latin-1') for sn_file in sn_files]
sn_data = pd.concat(sn_df)
sn_data.head()
# sn_df.head()
# Out:
#         number         opened_at            state         closed_at  \
# 0  RITM0507150  2017/01/01 11:02          Pending               NaN
# 1  RITM0507208   2017/01/02 4:47  Closed Complete  2017/01/03 12:34
# 2  RITM0507222   2017/01/02 5:12  Closed Complete   2017/01/02 7:05
# 3  RITM0507228   2017/01/02 5:51  Closed Complete  2017/01/04 11:57
# 4  RITM0507231   2017/01/02 6:00  Closed Complete  2017/01/04 17:34
#
#   u_interaction_id                                           cat_item  \
# 0              NaN            Modify Distribution List - Restrictions
# 1              NaN  Existing Network Folder/Shared Drive  Add/Remove
# 2              NaN                                  Add User to Group
# 3       SD09972560                    Service Manager 9 - User Access
# 4       SD09972577                                  Add User to Group
#
#               u_assignment_group
# 0      EAA_WINDOWS SERVICES_IMPL
# 1      EAA_WINDOWS SERVICES_IMPL
# 2      EAA_WINDOWS SERVICES_IMPL
# 3  EAA_APPLICATION SERVICES_IMPL
# 4      EAA_WINDOWS SERVICES_IMPL

# %%
sn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400000 entries, 0 to 399999
# Data columns (total 7 columns):
# number                400000 non-null object
# opened_at             400000 non-null object
# state                 400000 non-null object
# closed_at             394531 non-null object
# u_interaction_id      175560 non-null object
# cat_item              399998 non-null object
# u_assignment_group    400000 non-null object
# dtypes: object(7)
# memory usage: 24.4+ MB

# %%
# TO DO : Remove tickets having cat_item as null.
# 
sn_data.loc[sn_data['cat_item'].isnull()]

len(sn_data['number'].unique())

# TO DO : You can do time series analysis on the when tickets are opened. Average time taken to close tickets & on a per ticket basis. 
# 

type(sn_data['state'].value_counts())
#sn_win_app_data = sn_data.loc[sn_data['u_assignment_group'].isin(['EAA_WINDOWS SERVICES_IMPL' , 'EAA_APPLICATION SERVICES_IMPL'])]

sn_data['cat_item'].value_counts()
# Out:
# Add User to Group                                           115289
# Existing Network Folder/Shared Drive  Add/Remove            28820
# User Logon ID and Personal Mailbox                           23875
# Add Multiple Users to Group                                  20455
# Add Users to Generic Mailbox                                 14467
# Remove User from Domain Group                                11844
# Distribution List - Add/Remove Members                        9482
# Application - Password Reset/Unlock                           8802
# Create Application Group                                      8227
# Add Non-Primary ID to Group                                   7275
# Remove all User Access                                        6660
# Modify Domain Group - Owner Change                            6088
# Service Manager 9 - User Access                               5907
# Personal Drive Access                                         5605
# IA Code/Branch Access Add/Remove                              5390
# Enable / Disable Windows User Logon ID                        5297
# Create Distribution List                                      4337
# Modify Distribution List - Owner Change                       4336
# RightFax ID                                                   4244
# Remove Multiple Users from Group                              3484
# YouTube Access                                                3405
# Brokerage Team Folder Access                                  3245
# Service Manager 9 - Assignment Groups - Add/Remove Users      2884
# Outlook Display Name Change                                   2604
# New Account Request                                           2418
# Create New Shared / Generic Mailbox                           2397
# Modify Existing Windows User Logon ID                         2346
# Retrieve Domain Group Information                             2139
# Service ID - Create                                           2041
# Modify Service ID - Add to Group                              1964
#                                                              ...
# Website Access - Googlevideo                                     2
# Website Access - Netflix                                         2
# DATA Exchange  DX                                               2
# Non-Standard Request - CM US                                     2
# HSBCnet                                                          2
# Website Access - Twitter Sslopen                                 2
# Trade Count                                                      2
# Website Access - Rrdvenue                                        2
# AXIS                                                             1
# Sm9 Request Fulfillment Submission Form                          1
# Mortgage Servicing Platform (MSP)                                1
# Insurance Policy Audit Tool                                      1
# Credit Risk Monitoring                                           1
# Website Access - Firecall                                        1
# Website Access - Gambling Lottery                                1
# Website Access - Dataroom Login                                  1
# Snagit                                                           1
# Modify Firecall ID - Remove from Domain Group                    1
# Website Access - Googleplus                                      1
# Group CAS                                                        1
# Website Access - Yammer                                          1
# myRemotePC - Add                                                 1
# Reflection  for HP                                               1
# Website Access - Gambling bcwf                                   1
# QI US Source Income                                              1
# Mutual Fund Reconcillation & XREF                                1
# Attachmate Reflection Desktop 16                                 1
# Website Access - Swimsuit BCWF                                   1
# FX All                                                           1
# Individual Pension Plan (IPP)                                    1
# Name: cat_item, Length: 428, dtype: int64

# %%
import pandas as pd
import glob , os

#sn_columns = ['cat_item','u_assignment_group','opened_by.u_rbchrplatformdesc','opened_by.u_rbchrplatformcode','opened_by.u_rbcbufugudesc','opened_by.u_rbcbufugu']

sn_columns = ['Number','Item','Stage', 'State','Assignment Group']
sn_files = glob.glob(os.environ['PROJECT_DIR'] +  "rawdata\\sn\\*.csv")

sn_df = [pd.read_csv(sn_file , encoding='latin-1') for sn_file in sn_files]
#sn_df = [pd.read_csv(sn_file , encoding='latin-1', usecols=sn_columns) for sn_file in sn_files]

sn_data = pd.concat(sn_df)

# sn_data = pd.read_csv(os.environ['PROJECT_DIR']+'rawdata\\sn\\*.csv' , encoding='latin-1' , 
#                       usecols= sn_columns )

#Filter Service Now data to contain only Windows & Application Services ticket

#sn_data['u_assignment_group'].value_counts()

sn_win_app_data = sn_data.loc[sn_data['u_assignment_group'].isin(['EAA_WINDOWS SERVICES_IMPL' , 'EAA_APPLICATION SERVICES_IMPL'])]
#sn_win_app_data['u_assignment_group'].unique().tolist()

sn_win_app_data.rename(inplace = True , columns={'number' : 'RITM_Number' , 'u_assignment_group' : 'Assigned_Dept'})

#sn_win_app_data.groupby('cat_item')['u_assignment_group'].first() 
#len(sn_win_app_data)
# sn_win_app_data = sn_win_app_data.loc[sn_win_app_data['Stage'].isin(['Completed','Fulfillment'])]
#len(sn_data)
#41930
#sn_data['State'].value_counts()
len(sn_win_app_data)
# sn_data['Stage'][sn_data['State'] != 'Closed Complete']
# Out:
# 400000

# %%
#sn_win_app_data['Stage'].value_counts()

#len(sn_win_app_data['RITM_Number'].unique())
# Out:
# Completed      38588
# Fulfillment     3342
# Name: Stage, dtype: int64

# %%
#sn_win_app_data.loc[sn_win_app_data['RITM_Number'] == 'RITM1095465']
#RITM1757155
# sn_data = sn_win_app_data[['RITM_Number','Assigned_Dept','Item']]
# sn_data.shape
#len(sn_ritm)
# Out:
# (41930, 3)

# %%
#sn_win_app_data['State'].value_counts()
# Out:
# Closed Complete      41601
# Work in Progress       278
# Closed Incomplete       28
# Pending                 21
# Open                     2
# Name: State, dtype: int64

# %%
# len(sm9_data.loc[sm9_data['RBCMMPRITM'].isin(sn_ritm)])
# 22454

#sm9_data.loc[sm9_data['RBCMMPRITM'].isin(sn_ritm)].head()
#len(sm9_data.loc[sm9_data['RITM_Number'].isin(sn_ritm)])

#len(sm9_data.loc[sm9_data['RITM_Number'].isin(sn_ritm)])
#sn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41930 entries, 0 to 18000
# Data columns (total 3 columns):
# RITM_Number      41930 non-null object
# Assigned_Dept    41930 non-null object
# Item             41930 non-null object
# dtypes: object(3)
# memory usage: 1.3+ MB

# %%
# df_1 = sm9_data.loc[sm9_data['RBCMMPRITM'].isin(sn_ritm)]
# len(df_1['RBCMMPRITM'].unique())

# len(sm9_data.loc[sm9_data['RBCMMPRITM'].isin(sn_ritm)])

# %%
# df_1['RBCMMPRITM'].value_counts()

# %%
# sm9_data.columns
#sm9_data.rename(columns = {'RBCMMPRITM' : 'RITM_Number'} , inplace = True)
#sm9_data.loc[sm9_data['RITM_Number'] == 'RITM0583284']
#sm9_data.loc[sm9_data['RITM_Number'] == 'RITM0642300']

# %%
# sn_win_app_data.head()

# sn_win_app_data_1 = sn_win_app_data[['RITM_Number','Item','Assigned Dept']]
#sn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41930 entries, 0 to 18000
# Data columns (total 3 columns):
# RITM_Number      41930 non-null object
# Assigned_Dept    41930 non-null object
# Item             41930 non-null object
# dtypes: object(3)
# memory usage: 1.3+ MB

# %%
sn_win_app_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400000 entries, 0 to 399999
# Data columns (total 7 columns):
# RITM_Number         400000 non-null object
# opened_at           400000 non-null object
# state               400000 non-null object
# closed_at           394531 non-null object
# u_interaction_id    175560 non-null object
# cat_item            399998 non-null object
# Assigned_Dept       400000 non-null object
# dtypes: object(7)
# memory usage: 24.4+ MB

# %%
sm9_data_with_RITM.info()
len(sm9_data_with_RITM['RITM_Number'].unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200114 entries, 5 to 11148
# Data columns (total 8 columns):
# Number                 200114 non-null object
# RBC_Description        200107 non-null object
# Assigned_To            200114 non-null object
# Submit Date            200114 non-null object
# RITM_Number            200114 non-null object
# Assigned_Dept          200114 non-null object
# Close Date             200114 non-null object
# RBC_Line_Item_Title    200114 non-null object
# dtypes: object(8)
# memory usage: 13.7+ MB
# 173603

# %%
merged_data = pd.merge(sn_win_app_data ,sm9_data_with_RITM, on='RITM_Number', how='outer', indicator=True)
#merged_data.loc[merged_data['RITM_Number'] == 'RITM0583284']
#merged_data.head()
len(merged_data)
#256328
#merged_data.head(10)

# merged_data.loc[merged_data['RITM_Number'].isnull()]
# 33461
# Out:
# 439439

# %%
merged_data.head()
# Out:
#    RITM_Number         opened_at            state         closed_at  \
# 0  RITM0507150  2017/01/01 11:02          Pending               NaN
# 1  RITM0507208   2017/01/02 4:47  Closed Complete  2017/01/03 12:34
# 2  RITM0507222   2017/01/02 5:12  Closed Complete   2017/01/02 7:05
# 3  RITM0507228   2017/01/02 5:51  Closed Complete  2017/01/04 11:57
# 4  RITM0507231   2017/01/02 6:00  Closed Complete  2017/01/04 17:34
#
#   u_interaction_id                                           cat_item  \
# 0              NaN            Modify Distribution List - Restrictions
# 1              NaN  Existing Network Folder/Shared Drive  Add/Remove
# 2              NaN                                  Add User to Group
# 3       SD09972560                    Service Manager 9 - User Access
# 4       SD09972577                                  Add User to Group
#
#                  Assigned_Dept_x         Number  \
# 0      EAA_WINDOWS SERVICES_IMPL            NaN
# 1      EAA_WINDOWS SERVICES_IMPL            NaN
# 2      EAA_WINDOWS SERVICES_IMPL            NaN
# 3  EAA_APPLICATION SERVICES_IMPL  Q01423637-001
# 4      EAA_WINDOWS SERVICES_IMPL  Q01423652-001
#
#                                      RBC_Description Assigned_To  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3  Add - Service Manager 9 - User Access\r\n\r\nT...   195808886
# 4  Modify User - Add User to Group\r\nTHE REQUEST...   190899732
#
#        Submit Date                Assigned_Dept_y        Close Date  \
# 0              NaN                            NaN               NaN
# 1              NaN                            NaN               NaN
# 2              NaN                            NaN               NaN
# 3  2001/02/17 7:05  EAA_APPLICATION SERVICES_IMPL  2001/04/17 11:37
# 4  2001/02/17 7:10      EAA_WINDOWS SERVICES_IMPL  2001/04/17 17:18
#
#                                  RBC_Line_Item_Title     _merge
# 0                                                NaN  left_only
# 1                                                NaN  left_only
# 2                                                NaN  left_only
# 3              Add - Service Manager 9 - User Access       both
# 4  * ESC - Jan 4 - SEe updates -  Modify User - A...       both

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 439439 entries, 0 to 439438
# Data columns (total 15 columns):
# RITM_Number            439439 non-null object
# opened_at              425383 non-null object
# state                  425383 non-null object
# closed_at              419878 non-null object
# u_interaction_id       200943 non-null object
# cat_item               425381 non-null object
# Assigned_Dept_x        425383 non-null object
# Number                 200115 non-null object
# RBC_Description        200108 non-null object
# Assigned_To            200115 non-null object
# Submit Date            200115 non-null object
# Assigned_Dept_y        200115 non-null object
# Close Date             200115 non-null object
# RBC_Line_Item_Title    200115 non-null object
# _merge                 439439 non-null category
# dtypes: category(1), object(14)
# memory usage: 50.7+ MB

# %%
# For the merged dataset, tickets that have Assigned_To as null , a auto-resolved. Hence, we don't need to consider them for 
# recommendation

merged_data_assigned_tickets = merged_data.loc[~merged_data['Assigned_To'].isnull()]
merged_data_assigned_tickets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200115 entries, 3 to 439438
# Data columns (total 15 columns):
# RITM_Number            200115 non-null object
# opened_at              186059 non-null object
# state                  186059 non-null object
# closed_at              185783 non-null object
# u_interaction_id       186059 non-null object
# cat_item               186059 non-null object
# Assigned_Dept_x        186059 non-null object
# Number                 200115 non-null object
# RBC_Description        200108 non-null object
# Assigned_To            200115 non-null object
# Submit Date            200115 non-null object
# Assigned_Dept_y        200115 non-null object
# Close Date             200115 non-null object
# RBC_Line_Item_Title    200115 non-null object
# _merge                 200115 non-null category
# dtypes: category(1), object(14)
# memory usage: 23.1+ MB

# %%
merged_data_assigned_tickets['RITM_Number'].value_counts()
# Out:
# RITM1095465    20
# RITM0998292    13
# RITM1014016    10
# RITM1757155     9
# RITM1758818     8
# RITM1749623     8
# RITM1776707     8
# RITM1755280     8
# RITM1763194     8
# RITM1755382     8
# RITM1754602     8
# RITM1757770     8
# RITM1759640     8
# RITM1749905     8
# RITM1750739     8
# RITM1750210     8
# RITM1746208     8
# RITM1751230     8
# RITM1745856     8
# RITM2084166     8
# RITM1756430     8
# RITM1788867     8
# RITM1748222     8
# RITM1751427     8
# RITM1753514     8
# RITM1756790     8
# RITM1751765     8
# RITM1750405     8
# RITM1761178     8
# RITM1761150     8
#                ..
# RITM1022479     1
# RITM0526110     1
# RITM1114068     1
# RITM1364822     1
# RITM1245874     1
# RITM1032635     1
# RITM1487324     1
# RITM1961191     1
# RITM0875895     1
# RITM0680312     1
# RITM1227358     1
# RITM2083661     1
# RITM0982406     1
# RITM0777918     1
# RITM0315521     1
# RITM1845622     1
# RITM0575689     1
# RITM0911005     1
# RITM1393061     1
# RITM0848984     1
# RITM1879649     1
# RITM0925838     1
# RITM0799176     1
# RITM0518674     1
# RITM2062463     1
# RITM1344353     1
# RITM1962811     1
# RITM1698026     1
# RITM2127891     1
# RITM1397064     1
# Name: RITM_Number, Length: 173603, dtype: int64

# %%
#merged_data_assigned_tickets.loc[merged_data_assigned_tickets['RITM_Number'] == 'RITM1757770']
# Out:
#         RITM_Number         opened_at              state         closed_at  \
# 336941  RITM1757770  2018/02/27 13:50  Closed Incomplete  2018/03/26 12:59
# 336942  RITM1757770  2018/02/27 13:50  Closed Incomplete  2018/03/26 12:59
# 336943  RITM1757770  2018/02/27 13:50  Closed Incomplete  2018/03/26 12:59
# 336944  RITM1757770  2018/02/27 13:50  Closed Incomplete  2018/03/26 12:59
# 336945  RITM1757770  2018/02/27 13:50  Closed Incomplete  2018/03/26 12:59
# 336946  RITM1757770  2018/02/27 13:50  Closed Incomplete  2018/03/26 12:59
# 336947  RITM1757770  2018/02/27 13:50  Closed Incomplete  2018/03/26 12:59
# 336948  RITM1757770  2018/02/27 13:50  Closed Incomplete  2018/03/26 12:59
#
#        u_interaction_id                                           cat_item  \
# 336941       SD15819296  Skype for Business - For New User Requests OR ...
# 336942       SD15819296  Skype for Business - For New User Requests OR ...
# 336943       SD15819296  Skype for Business - For New User Requests OR ...
# 336944       SD15819296  Skype for Business - For New User Requests OR ...
# 336945       SD15819296  Skype for Business - For New User Requests OR ...
# 336946       SD15819296  Skype for Business - For New User Requests OR ...
# 336947       SD15819296  Skype for Business - For New User Requests OR ...
# 336948       SD15819296  Skype for Business - For New User Requests OR ...
#
#                   Assigned_Dept_x         Number  \
# 336941  EAA_WINDOWS SERVICES_IMPL  Q02351909-001
# 336942  EAA_WINDOWS SERVICES_IMPL  Q02284746-001
# 336943  EAA_WINDOWS SERVICES_IMPL  Q02303057-001
# 336944  EAA_WINDOWS SERVICES_IMPL  Q02313460-001
# 336945  EAA_WINDOWS SERVICES_IMPL  Q02317677-001
# 336946  EAA_WINDOWS SERVICES_IMPL  Q02324515-001
# 336947  EAA_WINDOWS SERVICES_IMPL  Q02326506-001
# 336948  EAA_WINDOWS SERVICES_IMPL  Q02334382-001
#
#                                           RBC_Description Assigned_To  \
# 336941  eSAM Add User to GroupAPP_UIH0_ENABLE_AUDIO_&_...   296472020
# 336942  eSAM Remove User from GroupAPP_UIH0_DISABLE_AU...   668401755
# 336943  eSAM Add User to GroupAPP_UIH0_ENABLE_AUDIO_&_...   936531946
# 336944  eSAM Remove User from GroupAPP_UIH0_DISABLE_AU...   936531946
# 336945  eSAM Add User to GroupAPP_UIH0_ENABLE_AUDIO_&_...   936531946
# 336946  eSAM Remove User from GroupAPP_UIH0_DISABLE_AU...   856836887
# 336947  eSAM Add User to GroupAPP_UIH0_ENABLE_AUDIO_&_...   936531946
# 336948  eSAM Remove User from GroupAPP_UIH0_DISABLE_AU...   296472020
#
#               Submit Date            Assigned_Dept_y         Close Date  \
# 336941  03/26/18 21:28:19  EAA_WINDOWS SERVICES_IMPL   2004/10/18 10:16
# 336942  02/27/18 15:01:09  EAA_WINDOWS SERVICES_IMPL   2003/06/18 11:16
# 336943   2003/06/18 18:06  EAA_WINDOWS SERVICES_IMPL   2003/09/18 13:20
# 336944   2003/09/18 17:10  EAA_WINDOWS SERVICES_IMPL   2003/12/18 16:40
# 336945   2003/12/18 17:14  EAA_WINDOWS SERVICES_IMPL  03/14/18 18:19:23
# 336946  03/14/18 20:17:39  EAA_WINDOWS SERVICES_IMPL  03/15/18 14:47:02
# 336947  03/15/18 15:20:05  EAA_WINDOWS SERVICES_IMPL  03/19/18 17:17:20
# 336948  03/19/18 18:23:50  EAA_WINDOWS SERVICES_IMPL  03/26/18 13:55:00
#
#                                       RBC_Line_Item_Title _merge
# 336941  eSAM Add User to GroupAPP_UIH0_ENABLE_AUDIO_&_...   both
# 336942  eSAM Remove User from GroupAPP_UIH0_DISABLE_AU...   both
# 336943  eSAM Add User to GroupAPP_UIH0_ENABLE_AUDIO_&_...   both
# 336944  eSAM Remove User from GroupAPP_UIH0_DISABLE_AU...   both
# 336945  eSAM Add User to GroupAPP_UIH0_ENABLE_AUDIO_&_...   both
# 336946  eSAM Remove User from GroupAPP_UIH0_DISABLE_AU...   both
# 336947  eSAM Add User to GroupAPP_UIH0_ENABLE_AUDIO_&_...   both
# 336948  eSAM Remove User from GroupAPP_UIH0_DISABLE_AU...   both

# %%
# How many tickets do we have that have RITM Number , but no cat_item 

merged_data_assigned_tickets_without_cat_item = merged_data_assigned_tickets.loc[merged_data_assigned_tickets['cat_item'].isnull()]
#merged_data_assigned_tickets_without_cat_item['_merge'].value_counts()

merged_data_assigned_tickets_without_cat_item[merged_data_assigned_tickets_without_cat_item['state'].isnull()]
#merged_data_assigned_tickets_without_cat_item['']
#merged_data_assigned_tickets_with_cat_item = merged_data_assigned_tickets.loc[~merged_data_assigned_tickets['cat_item'].isnull()]
#print(merged_data_assigned_tickets_with_cat_item.shape)
# Out:
#         RITM_Number opened_at state closed_at u_interaction_id cat_item  \
# 425383  RITM1732565       NaN   NaN       NaN              NaN      NaN
# 425384  RITM1789456       NaN   NaN       NaN              NaN      NaN
# 425385  RITM1815225       NaN   NaN       NaN              NaN      NaN
# 425386  RITM1829380       NaN   NaN       NaN              NaN      NaN
# 425387  RITM1846508       NaN   NaN       NaN              NaN      NaN
# 425388  RITM1838495       NaN   NaN       NaN              NaN      NaN
# 425389  RITM1838495       NaN   NaN       NaN              NaN      NaN
# 425390  RITM1841879       NaN   NaN       NaN              NaN      NaN
# 425391  RITM1795173       NaN   NaN       NaN              NaN      NaN
# 425392  RITM1795173       NaN   NaN       NaN              NaN      NaN
# 425393  RITM1869837       NaN   NaN       NaN              NaN      NaN
# 425394  RITM1871285       NaN   NaN       NaN              NaN      NaN
# 425395  RITM1749094       NaN   NaN       NaN              NaN      NaN
# 425396  RITM1865021       NaN   NaN       NaN              NaN      NaN
# 425397  RITM1869128       NaN   NaN       NaN              NaN      NaN
# 425398  RITM1792325       NaN   NaN       NaN              NaN      NaN
# 425399  RITM1792325       NaN   NaN       NaN              NaN      NaN
# 425400  RITM1838940       NaN   NaN       NaN              NaN      NaN
# 425401  RITM1858651       NaN   NaN       NaN              NaN      NaN
# 425402  RITM1869189       NaN   NaN       NaN              NaN      NaN
# 425403  RITM1867322       NaN   NaN       NaN              NaN      NaN
# 425404  RITM1869282       NaN   NaN       NaN              NaN      NaN
# 425405  RITM1878111       NaN   NaN       NaN              NaN      NaN
# 425406  RITM1821351       NaN   NaN       NaN              NaN      NaN
# 425407  RITM1829993       NaN   NaN       NaN              NaN      NaN
# 425408  RITM1829993       NaN   NaN       NaN              NaN      NaN
# 425409  RITM1863400       NaN   NaN       NaN              NaN      NaN
# 425410  RITM1860097       NaN   NaN       NaN              NaN      NaN
# 425411  RITM1863680       NaN   NaN       NaN              NaN      NaN
# 425412  RITM1863680       NaN   NaN       NaN              NaN      NaN
# ...             ...       ...   ...       ...              ...      ...
# 439409  RITM1242218       NaN   NaN       NaN              NaN      NaN
# 439410  RITM0367084       NaN   NaN       NaN              NaN      NaN
# 439411  RITM0366305       NaN   NaN       NaN              NaN      NaN
# 439412  RITM0367302       NaN   NaN       NaN              NaN      NaN
# 439413  RITM0367394       NaN   NaN       NaN              NaN      NaN
# 439414  RITM0366234       NaN   NaN       NaN              NaN      NaN
# 439415  RITM0367050       NaN   NaN       NaN              NaN      NaN
# 439416  RITM0367608       NaN   NaN       NaN              NaN      NaN
# 439417  RITM0366290       NaN   NaN       NaN              NaN      NaN
# 439418  RITM0366297       NaN   NaN       NaN              NaN      NaN
# 439419  RITM0366316       NaN   NaN       NaN              NaN      NaN
# 439420  RITM0366320       NaN   NaN       NaN              NaN      NaN
# 439421  RITM0366082       NaN   NaN       NaN              NaN      NaN
# 439422  RITM0366287       NaN   NaN       NaN              NaN      NaN
# 439423  RITM0367491       NaN   NaN       NaN              NaN      NaN
# 439424  RITM0367080       NaN   NaN       NaN              NaN      NaN
# 439425  RITM0367090       NaN   NaN       NaN              NaN      NaN
# 439426  RITM0366828       NaN   NaN       NaN              NaN      NaN
# 439427  RITM0367312       NaN   NaN       NaN              NaN      NaN
# 439428  RITM0366292       NaN   NaN       NaN              NaN      NaN
# 439429  RITM0367089       NaN   NaN       NaN              NaN      NaN
# 439430  RITM0367553       NaN   NaN       NaN              NaN      NaN
# 439431  RITM0367086       NaN   NaN       NaN              NaN      NaN
# 439432  RITM0367002       NaN   NaN       NaN              NaN      NaN
# 439433  RITM0367083       NaN   NaN       NaN              NaN      NaN
# 439434  RITM0367588       NaN   NaN       NaN              NaN      NaN
# 439435  RITM0366993       NaN   NaN       NaN              NaN      NaN
# 439436  RITM1245991       NaN   NaN       NaN              NaN      NaN
# 439437  RITM1247207       NaN   NaN       NaN              NaN      NaN
# 439438  RITM1251200       NaN   NaN       NaN              NaN      NaN
#
#        Assigned_Dept_x         Number  \
# 425383             NaN  Q02268854-002
# 425384             NaN  Q02303786-002
# 425385             NaN  Q02321589-002
# 425386             NaN  Q02328981-002
# 425387             NaN  Q02337904-002
# 425388             NaN  Q02333819-001
# 425389             NaN  Q02333819-002
# 425390             NaN  Q02336323-001
# 425391             NaN  Q02308231-003
# 425392             NaN  Q02308231-002
# 425393             NaN  Q02353181-002
# 425394             NaN  Q02354020-003
# 425395             NaN  Q02278563-002
# 425396             NaN  Q02350332-002
# 425397             NaN  Q02352774-002
# 425398             NaN  Q02305918-003
# 425399             NaN  Q02305918-002
# 425400             NaN  Q02333983-002
# 425401             NaN  Q02344379-002
# 425402             NaN  Q02352808-002
# 425403             NaN  Q02351583-002
# 425404             NaN  Q02352845-002
# 425405             NaN  Q02358177-002
# 425406             NaN  Q02328203-002
# 425407             NaN  Q02330228-003
# 425408             NaN  Q02330228-004
# 425409             NaN  Q02349198-002
# 425410             NaN  Q02345067-002
# 425411             NaN  Q02349558-003
# 425412             NaN  Q02349558-002
# ...                ...            ...
# 439409             NaN  Q01972182-001
# 439410             NaN  Q01973903-001
# 439411             NaN  Q01973904-001
# 439412             NaN  Q01973905-001
# 439413             NaN  Q01973906-001
# 439414             NaN  Q01973907-001
# 439415             NaN  Q01973908-001
# 439416             NaN  Q01973909-001
# 439417             NaN  Q01973910-001
# 439418             NaN  Q01973911-001
# 439419             NaN  Q01973912-001
# 439420             NaN  Q01973913-001
# 439421             NaN  Q01973914-001
# 439422             NaN  Q01973915-001
# 439423             NaN  Q01973916-001
# 439424             NaN  Q01973917-001
# 439425             NaN  Q01973918-001
# 439426             NaN  Q01973919-001
# 439427             NaN  Q01973920-001
# 439428             NaN  Q01973921-001
# 439429             NaN  Q01973922-001
# 439430             NaN  Q01973923-001
# 439431             NaN  Q01973925-001
# 439432             NaN  Q01973929-001
# 439433             NaN  Q01973931-001
# 439434             NaN  Q01973933-001
# 439435             NaN  Q01973935-001
# 439436             NaN  Q01974587-001
# 439437             NaN  Q01975161-001
# 439438             NaN  Q01977805-001
#
#                                           RBC_Description Assigned_To  \
# 425383  PLEASE REMOVE THE FOLLOWING ACCESS\r\n\r\nUser...   310294822
# 425384  Hi Team,\r\n\r\nPlease amend the below access ...   310294822
# 425385  CMACS-12530 - Q02321589-001 - SWIFT Messaging ...   310294822
# 425386  CMACS-12683 - Q02328981-001 - SWIFT Messaging ...   310294822
# 425387  CMACS-12813 - Q02337904-001 - SWIFT Messaging ...   310294822
# 425388  myMarketPlace Support - Enterprise Security Ac...   698544350
# 425389  myMarketPlace Support - Enterprise Security Ac...   698544350
# 425390  myMarketPlace Support - Tammy Clairmont\r\n\r\...   191458827
# 425391  Please permission the following role changes a...   310294822
# 425392  Please complete the following role changes and...   310294822
# 425393  Hello Team, please permission the following,\r...   310294822
# 425394  Hi Team,\r\n\r\nPlease permission users below ...   310294822
# 425395  Hi team,\r\n\r\nPlease permission the user bel...   310294822
# 425396  CMACS-12994 - Q02350332-001 - SunGard Apex (SM...   310294822
# 425397  Please remove the following access and advise ...   310294822
# 425398  Hi team,\r\n\r\nPlease permission the below us...   310294822
# 425399  Hi Team,\r\n\r\nPlease permission the below us...   310294822
# 425400  Hi Team,\r\n\r\nPlease permission the user bel...   310294822
# 425401  Hi team,\r\n\r\nPlease permission the user bel...   310294822
# 425402  Application #1:\r\n\r\nUser Name: Chen, Jian M...   310294822
# 425403  CMACS-13035 - Q02351583-001 - GIMAC - Market D...   310294822
# 425404  CMACS-13109 - Q02352845-001 - Loanet (UHZ0) fo...   310294822
# 425405  HI TEAM,\r\nPLEASE CREATE A RIMMS LONDON DEALE...   310294822
# 425406  Hello Team, please permission the following,\r...   310294822
# 425407  Please permission the following access and adv...   310294822
# 425408  Please permission the following access and adv...   310294822
# 425409  Please create RIMMS Dealer IDs for the followi...   310294822
# 425410  Hi team,\r\n\r\nPlease create an OPICS FI Deal...   310294822
# 425411  Hello Team, please permission the following,\r...   310294822
# 425412  Hello Team, please map Kaviena Krishnarajah's ...   631444387
# ...                                                   ...         ...
# 439409  myMarketPlace - Escalation (RITM1209974)\r\n\r...   191918473
# 439410  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439411  Remove User from Group\r\nTHE REQUEST HAS BEEN...   787489756
# 439412  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439413  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439414  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439415  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439416  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439417  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439418  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439419  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439420  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439421  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439422  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439423  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439424  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439425  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439426  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439427  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439428  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439429  Remove User from Group\r\nTHE REQUEST HAS BEEN...   787489756
# 439430  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439431  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439432  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439433  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439434  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439435  Remove User from Group\r\nTHE REQUEST HAS BEEN...   850772930
# 439436  myMarketPlace - Escalation (RITM1245942)\r\n\r...   191918473
# 439437  myMarketPlace - Escalation (RITM1216375)\r\n\r...   178412342
# 439438  myMarketPlace Support - other\r\nRequestor Inf...   631444387
#
#               Submit Date                Assigned_Dept_y         Close Date  \
# 425383   2003/07/18 13:17  EAA_APPLICATION SERVICES_IMPL  04/13/18 13:36:03
# 425384   2003/07/18 11:25  EAA_APPLICATION SERVICES_IMPL   2004/03/18 11:31
# 425385  03/15/18 07:44:33  EAA_APPLICATION SERVICES_IMPL   2004/03/18 14:37
# 425386  03/22/18 13:00:56  EAA_APPLICATION SERVICES_IMPL   2004/02/18 12:39
# 425387  03/22/18 13:17:46  EAA_APPLICATION SERVICES_IMPL   2004/02/18 12:37
# 425388  03/19/18 15:12:15  EAA_APPLICATION SERVICES_IMPL    2004/02/18 8:48
# 425389   2004/03/18 16:20  EAA_APPLICATION SERVICES_IMPL   2004/03/18 16:26
# 425390  03/20/18 11:15:34  EAA_APPLICATION SERVICES_IMPL  04/13/18 12:03:20
# 425391  03/26/18 16:12:16  EAA_APPLICATION SERVICES_IMPL   2004/02/18 17:30
# 425392  03/26/18 11:16:11  EAA_APPLICATION SERVICES_IMPL   2004/03/18 13:07
# 425393  03/27/18 13:41:41  EAA_APPLICATION SERVICES_IMPL   2004/03/18 14:49
# 425394  03/28/18 09:01:18  EAA_APPLICATION SERVICES_IMPL   2004/03/18 15:13
# 425395  03/26/18 14:09:02  EAA_APPLICATION SERVICES_IMPL   2004/02/18 17:18
# 425396  03/26/18 14:51:28  EAA_APPLICATION SERVICES_IMPL   2004/02/18 17:27
# 425397  03/27/18 11:30:44  EAA_APPLICATION SERVICES_IMPL   2004/03/18 13:47
# 425398  03/27/18 14:33:24  EAA_APPLICATION SERVICES_IMPL   2004/03/18 14:59
# 425399  03/26/18 11:09:20  EAA_APPLICATION SERVICES_IMPL   2004/02/18 14:58
# 425400  03/26/18 11:22:06  EAA_APPLICATION SERVICES_IMPL   2004/02/18 17:04
# 425401  03/26/18 11:44:14  EAA_APPLICATION SERVICES_IMPL   2004/02/18 17:10
# 425402  03/27/18 12:06:16  EAA_APPLICATION SERVICES_IMPL   2004/03/18 14:36
# 425403  03/28/18 12:47:01  EAA_APPLICATION SERVICES_IMPL   2004/05/18 13:40
# 425404  03/28/18 12:57:19  EAA_APPLICATION SERVICES_IMPL   2004/03/18 16:57
# 425405  03/29/18 13:50:07  EAA_APPLICATION SERVICES_IMPL   2004/03/18 18:38
# 425406  03/26/18 10:33:13  EAA_APPLICATION SERVICES_IMPL   2004/02/18 14:36
# 425407  03/26/18 10:55:25  EAA_APPLICATION SERVICES_IMPL   2004/02/18 14:43
# 425408  03/26/18 10:57:58  EAA_APPLICATION SERVICES_IMPL   2004/02/18 15:08
# 425409  03/26/18 14:13:44  EAA_APPLICATION SERVICES_IMPL   2004/02/18 17:24
# 425410  03/27/18 11:04:41  EAA_APPLICATION SERVICES_IMPL   2004/03/18 13:15
# 425411  03/28/18 09:46:40  EAA_APPLICATION SERVICES_IMPL   2004/03/18 15:20
# 425412  03/27/18 10:42:58      EAA_WINDOWS SERVICES_IMPL    2004/02/18 6:42
# ...                   ...                            ...                ...
# 439409  09/27/17 10:53:34      EAA_WINDOWS SERVICES_IMPL  09/28/17 07:15:56
# 439410  09/28/17 00:01:23      EAA_WINDOWS SERVICES_IMPL  09/29/17 08:24:21
# 439411  09/28/17 00:01:25      EAA_WINDOWS SERVICES_IMPL  09/29/17 12:23:35
# 439412  09/28/17 00:01:27      EAA_WINDOWS SERVICES_IMPL  09/29/17 08:30:16
# 439413  09/28/17 00:01:28      EAA_WINDOWS SERVICES_IMPL  09/29/17 08:40:57
# 439414  09/28/17 00:02:33      EAA_WINDOWS SERVICES_IMPL  09/29/17 08:50:12
# 439415  09/28/17 00:02:34      EAA_WINDOWS SERVICES_IMPL  09/29/17 08:58:26
# 439416  09/28/17 00:02:35      EAA_WINDOWS SERVICES_IMPL  09/29/17 09:08:13
# 439417  09/28/17 00:02:36      EAA_WINDOWS SERVICES_IMPL  09/29/17 09:17:33
# 439418  09/28/17 00:02:38      EAA_WINDOWS SERVICES_IMPL  09/29/17 09:29:43
# 439419  09/28/17 00:02:39      EAA_WINDOWS SERVICES_IMPL  09/29/17 09:40:08
# 439420  09/28/17 00:02:40      EAA_WINDOWS SERVICES_IMPL  09/29/17 09:52:22
# 439421  09/28/17 00:02:42      EAA_WINDOWS SERVICES_IMPL  09/29/17 09:58:43
# 439422  09/28/17 00:02:44      EAA_WINDOWS SERVICES_IMPL  09/29/17 10:10:55
# 439423  09/28/17 00:02:45      EAA_WINDOWS SERVICES_IMPL  09/29/17 10:17:51
# 439424  09/28/17 00:02:47      EAA_WINDOWS SERVICES_IMPL  09/29/17 10:32:32
# 439425  09/28/17 00:02:49      EAA_WINDOWS SERVICES_IMPL  09/29/17 10:54:09
# 439426  09/28/17 00:02:50      EAA_WINDOWS SERVICES_IMPL  09/29/17 10:54:47
# 439427  09/28/17 00:02:52      EAA_WINDOWS SERVICES_IMPL  09/29/17 11:03:57
# 439428  09/28/17 00:02:53      EAA_WINDOWS SERVICES_IMPL  09/29/17 11:11:46
# 439429  09/28/17 00:02:55      EAA_WINDOWS SERVICES_IMPL  09/29/17 14:48:32
# 439430  09/28/17 00:02:56      EAA_WINDOWS SERVICES_IMPL  09/29/17 11:19:36
# 439431  09/28/17 00:02:59      EAA_WINDOWS SERVICES_IMPL  09/29/17 11:26:07
# 439432  09/28/17 00:03:06      EAA_WINDOWS SERVICES_IMPL  09/29/17 11:33:12
# 439433  09/28/17 00:03:08      EAA_WINDOWS SERVICES_IMPL  09/29/17 11:39:55
# 439434  09/28/17 00:03:11      EAA_WINDOWS SERVICES_IMPL  09/29/17 11:47:37
# 439435  09/28/17 00:03:14      EAA_WINDOWS SERVICES_IMPL  09/29/17 11:55:16
# 439436  09/28/17 09:28:18      EAA_WINDOWS SERVICES_IMPL  09/28/17 12:55:39
# 439437  09/28/17 11:53:38      EAA_WINDOWS SERVICES_IMPL  09/29/17 08:32:36
# 439438  09/29/17 11:13:14      EAA_WINDOWS SERVICES_IMPL  09/29/17 11:22:39
#
#                                       RBC_Line_Item_Title      _merge
# 425383           * 03/13 PO - RTP -AACG REMOVAL FICC RTTM  right_only
# 425384  03/13 PO - RTP AACG - Application Access Reque...  right_only
# 425385  04/03 PO - RTP - AACG - SWIFT Messaging Platfo...  right_only
# 425386  03/29 PO - RTP - AACG - SWIFT Messaging Platfo...  right_only
# 425387  03/29 PO - RTP - AACG - SWIFT Messaging Platfo...  right_only
# 425388  03/29 - PA - preprod MDSS (GIMAC) - myMarketPl...  right_only
# 425389  myMarketPlace Support - Enterprise Security Ac...  right_only
# 425390            myMarketPlace Support - Tammy Clairmont  right_only
# 425391        RTP AACG - E-OPS/IRIS - (ZPV0) ROLE CHANGES  right_only
# 425392  RTP AACG - RIMMS London, New York + Toronto RO...  right_only
# 425393          RTP AACG - LOANET(UHZ0) - Ronald Thompson  right_only
# 425394  RTP AACG - Application Access Request: Alexand...  right_only
# 425395      RTP AACG - Application Access Request: Shu Ye  right_only
# 425396                   RTP - AACG - SunGard Apex (SMB0)  right_only
# 425397  RTP AACG - REMOVAL - ATLAS (YVL0) + E-OPS/IRIS...  right_only
# 425398  RTP AACG - Application Access Request: Lula Kinaj  right_only
# 425399  RTP AACG - Application Access Request: Lula Kinaj  right_only
# 425400  RTP AACG - Application Access Request: Daniel ...  right_only
# 425401  RTP AACG - Application and Install Request: Ja...  right_only
# 425402         04/03 PO - RTP AACG - Multiple App Removal  right_only
# 425403  RTP - AACG - GIMAC - Market Data and Scenario ...  right_only
# 425404                         RTP - AACG - Loanet (UHZ0)  right_only
# 425405                  RTP AACG - RIMMS LONDON DEALER ID  right_only
# 425406     RTP AACG - RIMMS Toronto(8L00) - Elisa Sicilia  right_only
# 425407  RTp AACG - RIMMS London (NR00) & RIMMS Toronto...  right_only
# 425408  04/02 PO - RTP AACG - SWIFT Messaging Platform...  right_only
# 425409  RTP AACG - RATS - London (YQY0) - RIMMS Dealer ID  right_only
# 425410  RTP AACG - Application Access Request: Carmela...  right_only
# 425411  RTP AACG - Workflow London(ZNP0) - Kaviena Kri...  right_only
# 425412  RTP AACG - H Drive mapped to the user's Termin...  right_only
# ...                                                   ...         ...
# 439409  10/03-PA  * ESC 09/27 - Add user to group - my...  right_only
# 439410                             Remove User from Group  right_only
# 439411                             Remove User from Group  right_only
# 439412                             Remove User from Group  right_only
# 439413                             Remove User from Group  right_only
# 439414                             Remove User from Group  right_only
# 439415                             Remove User from Group  right_only
# 439416                             Remove User from Group  right_only
# 439417                             Remove User from Group  right_only
# 439418                             Remove User from Group  right_only
# 439419                             Remove User from Group  right_only
# 439420                             Remove User from Group  right_only
# 439421                             Remove User from Group  right_only
# 439422                             Remove User from Group  right_only
# 439423                             Remove User from Group  right_only
# 439424                             Remove User from Group  right_only
# 439425                             Remove User from Group  right_only
# 439426                             Remove User from Group  right_only
# 439427                             Remove User from Group  right_only
# 439428                             Remove User from Group  right_only
# 439429                             Remove User from Group  right_only
# 439430                             Remove User from Group  right_only
# 439431                             Remove User from Group  right_only
# 439432                             Remove User from Group  right_only
# 439433                             Remove User from Group  right_only
# 439434                             Remove User from Group  right_only
# 439435                             Remove User from Group  right_only
# 439436  * Remove user from group - myMarketPlace - Esc...  right_only
# 439437  * ESC 09/28 - Triage - myMarketPlace - Escalat...  right_only
# 439438                      myMarketPlace Support - other  right_only
#
# [14056 rows x 15 columns]

# %%
# All tickets which are not assigned to an analyst 

# We need to ensure we don't consider tickets that are not present in SM9, since they are auto-resolved. Do thhis only after 
# you receive confirmation on email sent out to Nadia / Blake on 19th June 2018. 

merged_data_not_assigned = merged_data.loc[merged_data['Assigned_To'].isnull()]
merged_data_not_assigned['Item'].value_counts()
merged_data_not_assigned.to_csv(path_or_buf= os.environ['PROJECT_DIR'] + "\\temp\\merged_data_not_assigned.csv" , encoding="Latin-1" , index = False)
#len(merged_data_not_assigned)
#22753

# Tickets that are assigned to analyst 

# merged_data_assigned = merged_data.loc[~merged_data['Assigned_To'].isnull()]
# len(merged_data_assigned)
#233575

#merged_data_assigned['RITM_Number'].value_counts()

# %%
merged_data_assigned.loc[merged_data_assigned['RITM_Number'] == 'RITM0998292']
# Out:
#         RITM_Number Assigned_Dept_x Item         Number Assigned_To  \
# 200384  RITM0998292             NaN  NaN  Q01810656-001   322930777
# 200385  RITM0998292             NaN  NaN  Q01810666-001   322930777
# 200386  RITM0998292             NaN  NaN  Q01810692-001   322930777
# 200387  RITM0998292             NaN  NaN  Q01810699-001   322930777
# 200388  RITM0998292             NaN  NaN  Q01810704-001   322930777
# 200389  RITM0998292             NaN  NaN  Q01810707-001   322930777
# 200390  RITM0998292             NaN  NaN  Q01810713-001   322930777
# 200391  RITM0998292             NaN  NaN  Q01810715-001   322930777
# 200392  RITM0998292             NaN  NaN  Q01810719-001   322930777
# 200393  RITM0998292             NaN  NaN  Q01810742-001   322930777
# 200394  RITM0998292             NaN  NaN  Q01810744-001   322930777
# 200395  RITM0998292             NaN  NaN  Q01810746-001   322930777
# 200396  RITM0998292             NaN  NaN  Q01810760-001   322930777
#
#               Submit Date            Assigned_Dept_y         Close Date  \
# 200384  07/18/17 13:49:24  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:40:49
# 200385  07/18/17 13:50:46  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:42:24
# 200386  07/18/17 13:55:55  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:41:01
# 200387  07/18/17 13:57:17  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:42:59
# 200388  07/18/17 13:58:31  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:41:12
# 200389  07/18/17 13:59:40  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:42:36
# 200390  07/18/17 14:01:00  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:41:25
# 200391  07/18/17 14:02:11  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:43:56
# 200392  07/18/17 14:03:25  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:41:39
# 200393  07/18/17 14:06:28  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:42:46
# 200394  07/18/17 14:07:43  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:41:51
# 200395  07/18/17 14:07:49  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:43:10
# 200396  07/18/17 14:10:18  EAA_WINDOWS SERVICES_IMPL  07/19/17 08:42:05
#
#                          RBC_Line_Item_Title
# 200384  Personal Mailbox Access - Add/Remove
# 200385  Personal Mailbox Access - Add/Remove
# 200386  Personal Mailbox Access - Add/Remove
# 200387  Personal Mailbox Access - Add/Remove
# 200388  Personal Mailbox Access - Add/Remove
# 200389  Personal Mailbox Access - Add/Remove
# 200390  Personal Mailbox Access - Add/Remove
# 200391  Personal Mailbox Access - Add/Remove
# 200392  Personal Mailbox Access - Add/Remove
# 200393  Personal Mailbox Access - Add/Remove
# 200394  Personal Mailbox Access - Add/Remove
# 200395  Personal Mailbox Access - Add/Remove
# 200396  Personal Mailbox Access - Add/Remove

# %%
# Give me all tickets / rows where no column has NaN 

#len(merged_data.dropna(axis=0 , how="any" ))
#22215

#merged_data.loc[merged_data.isnull().  ]

#len(merged_data)
#264095

merged_data.dropna(axis=0 , how="any")

# %%
# Analysis of ticket present in Service Now, but not in SM9. 
# NOTE : WE ARE YET TO HAVE SERVICE NOW DATA FOR 2018. 

sn_data.info()
sm9_data.loc[sm9_data['RITM_Number'] == 'RITM1095465']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41930 entries, 0 to 18000
# Data columns (total 3 columns):
# RITM_Number      41930 non-null object
# Assigned_Dept    41930 non-null object
# Item             41930 non-null object
# dtypes: object(3)
# memory usage: 1.3+ MB
#      Assigned_To  RITM_Number                  Assigned_Dept  \
# 8832   318215316  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 8833   318215316  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 8834   310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 8835   318215316  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 8836   318215316  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 28     310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 89     310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 90     310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 5009   310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 97     310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 98     310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 99     310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 100    543589881  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 101    310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 102    310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 172    310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 173    310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 183    310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 184    310294822  RITM1095465  EAA_APPLICATION SERVICES_IMPL
# 4660   698544350  RITM1095465  EAA_APPLICATION SERVICES_IMPL
#
#                                     RBC_Line_Item_Title
# 8832                                   RTP - DFR (XDQ0)
# 8833                          RTP - ICI - IMPACT (XTT0)
# 8834                                RTP - IMatch (YWH0)
# 8835                                RTP - P&L NY (XZT0)
# 8836                            RTP - SLIM - MAH (XAU0)
# 28      RTP - SWIFT Messaging Platform - Clarity (VMD0)
# 89                                  RTP - IMatch (YWH0)
# 90         RTP - Counter-party credit risk - CCR (SIF0)
# 5009                               RTP -  IMatch (YWH0)
# 97                          RTP - ADP Gloss - TE (ZTX0)
# 98                            RTP - E-OPS/IRIS - (ZPV0)
# 99                              RTP - Smart Loan (WMM0)
# 100                      RTP - Yieldbroker Debts (WWF0)
# 101                     RTP - Workflow Atlas/NDF (ZPX0)
# 102                      RTP - Workflow-OpenLink (WOK0)
# 172   RTP - SunGard Apex fro Orain (SMB0) - Please u...
# 173                                RTP - DSPRIME (ZMI0)
# 183                      RTP - Workflow - London (ZNP0)
# 184                     RTP - Workflow - Toronto (YWQ0)
# 4660                          RTP - E-OPS/IRIS - (ZPV0)

# %%
# Get me data where 
merged_data_assigned_temp = merged_data_assigned.loc[~merged_data_assigned['Item'].isnull()]
merged_data_assigned_temp.loc[merged_data_assigned_temp['Item'].str.contains('Personal Mailbox Access')]
# Out:
#        RITM_Number            Assigned_Dept_x  \
# 59     RITM0507545  EAA_WINDOWS SERVICES_IMPL
# 245    RITM0508269  EAA_WINDOWS SERVICES_IMPL
# 402    RITM0508807  EAA_WINDOWS SERVICES_IMPL
# 432    RITM0508898  EAA_WINDOWS SERVICES_IMPL
# 517    RITM0509231  EAA_WINDOWS SERVICES_IMPL
# 605    RITM0509514  EAA_WINDOWS SERVICES_IMPL
# 798    RITM0510377  EAA_WINDOWS SERVICES_IMPL
# 871    RITM0510599  EAA_WINDOWS SERVICES_IMPL
# 1044   RITM0511167  EAA_WINDOWS SERVICES_IMPL
# 1065   RITM0511241  EAA_WINDOWS SERVICES_IMPL
# 1111   RITM0511415  EAA_WINDOWS SERVICES_IMPL
# 1126   RITM0511478  EAA_WINDOWS SERVICES_IMPL
# 1172   RITM0511642  EAA_WINDOWS SERVICES_IMPL
# 1309   RITM0512027  EAA_WINDOWS SERVICES_IMPL
# 1310   RITM0512027  EAA_WINDOWS SERVICES_IMPL
# 1311   RITM0512027  EAA_WINDOWS SERVICES_IMPL
# 1384   RITM0512348  EAA_WINDOWS SERVICES_IMPL
# 1849   RITM0513814  EAA_WINDOWS SERVICES_IMPL
# 2121   RITM0514670  EAA_WINDOWS SERVICES_IMPL
# 2142   RITM0514738  EAA_WINDOWS SERVICES_IMPL
# 2204   RITM0515024  EAA_WINDOWS SERVICES_IMPL
# 2302   RITM0515337  EAA_WINDOWS SERVICES_IMPL
# 2303   RITM0515339  EAA_WINDOWS SERVICES_IMPL
# 2364   RITM0515640  EAA_WINDOWS SERVICES_IMPL
# 2534   RITM0516218  EAA_WINDOWS SERVICES_IMPL
# 2563   RITM0516335  EAA_WINDOWS SERVICES_IMPL
# 2766   RITM0516976  EAA_WINDOWS SERVICES_IMPL
# 2842   RITM0517226  EAA_WINDOWS SERVICES_IMPL
# 3082   RITM0518067  EAA_WINDOWS SERVICES_IMPL
# 3390   RITM0519138  EAA_WINDOWS SERVICES_IMPL
# ...            ...                        ...
# 34265  RITM0635052  EAA_WINDOWS SERVICES_IMPL
# 34432  RITM0635565  EAA_WINDOWS SERVICES_IMPL
# 35448  RITM0639490  EAA_WINDOWS SERVICES_IMPL
# 35843  RITM0641160  EAA_WINDOWS SERVICES_IMPL
# 36126  RITM0642339  EAA_WINDOWS SERVICES_IMPL
# 36230  RITM0642912  EAA_WINDOWS SERVICES_IMPL
# 36307  RITM0643533  EAA_WINDOWS SERVICES_IMPL
# 37329  RITM0647806  EAA_WINDOWS SERVICES_IMPL
# 37477  RITM0648321  EAA_WINDOWS SERVICES_IMPL
# 37505  RITM0648449  EAA_WINDOWS SERVICES_IMPL
# 37573  RITM0648759  EAA_WINDOWS SERVICES_IMPL
# 37905  RITM0650348  EAA_WINDOWS SERVICES_IMPL
# 38531  RITM0653418  EAA_WINDOWS SERVICES_IMPL
# 38606  RITM0653613  EAA_WINDOWS SERVICES_IMPL
# 38878  RITM0654608  EAA_WINDOWS SERVICES_IMPL
# 39017  RITM0655444  EAA_WINDOWS SERVICES_IMPL
# 39223  RITM0656466  EAA_WINDOWS SERVICES_IMPL
# 39486  RITM0658038  EAA_WINDOWS SERVICES_IMPL
# 39898  RITM0660060  EAA_WINDOWS SERVICES_IMPL
# 40080  RITM0660721  EAA_WINDOWS SERVICES_IMPL
# 40344  RITM0662150  EAA_WINDOWS SERVICES_IMPL
# 40562  RITM0663170  EAA_WINDOWS SERVICES_IMPL
# 41190  RITM0666379  EAA_WINDOWS SERVICES_IMPL
# 41806  RITM0669906  EAA_WINDOWS SERVICES_IMPL
# 41908  RITM0670262  EAA_WINDOWS SERVICES_IMPL
# 42441  RITM0672852  EAA_WINDOWS SERVICES_IMPL
# 42609  RITM0673470  EAA_WINDOWS SERVICES_IMPL
# 43080  RITM0675904  EAA_WINDOWS SERVICES_IMPL
# 43629  RITM0678524  EAA_WINDOWS SERVICES_IMPL
# 44188  RITM0681337  EAA_WINDOWS SERVICES_IMPL
#
#                                        Item         Number Assigned_To  \
# 59     Personal Mailbox Access - Add/Remove  Q01424688-001   180626202
# 245    Personal Mailbox Access - Add/Remove  Q01464504-001   318801727
# 402    Personal Mailbox Access - Add/Remove  Q01426417-001   180190019
# 432    Personal Mailbox Access - Add/Remove  Q01426496-001   180190019
# 517    Personal Mailbox Access - Add/Remove  Q01426788-001   543598601
# 605    Personal Mailbox Access - Add/Remove  Q01427064-001   318801727
# 798    Personal Mailbox Access - Add/Remove  Q01428037-001   315467852
# 871    Personal Mailbox Access - Add/Remove  Q01433372-001   294555602
# 1044   Personal Mailbox Access - Add/Remove  Q01450192-001   315467852
# 1065   Personal Mailbox Access - Add/Remove  Q01428686-001   315467852
# 1111   Personal Mailbox Access - Add/Remove  Q01436258-001   180190019
# 1126   Personal Mailbox Access - Add/Remove  Q01451586-001   956519110
# 1172   Personal Mailbox Access - Add/Remove  Q01428972-001   315467852
# 1309   Personal Mailbox Access - Add/Remove  Q01429281-001   956519110
# 1310   Personal Mailbox Access - Add/Remove  Q01429281-002   956519110
# 1311   Personal Mailbox Access - Add/Remove  Q01429281-003   936531946
# 1384   Personal Mailbox Access - Add/Remove  Q01429559-001   315467852
# 1849   Personal Mailbox Access - Add/Remove  Q01435746-001   180626202
# 2121   Personal Mailbox Access - Add/Remove  Q01431944-001   956519110
# 2142   Personal Mailbox Access - Add/Remove  Q01432038-001   190899732
# 2204   Personal Mailbox Access - Add/Remove  Q01432467-001   180626202
# 2302   Personal Mailbox Access - Add/Remove  Q01434100-001   191918473
# 2303   Personal Mailbox Access - Add/Remove  Q01432546-001   191918473
# 2364   Personal Mailbox Access - Add/Remove  Q01433086-001   522079805
# 2534   Personal Mailbox Access - Add/Remove  Q01433769-001   322888413
# 2563   Personal Mailbox Access - Add/Remove  Q01451950-001   956519110
# 2766   Personal Mailbox Access - Add/Remove  Q01434566-001   180190019
# 2842   Personal Mailbox Access - Add/Remove  Q01434787-001   180190019
# 3082   Personal Mailbox Access - Add/Remove  Q01436346-001   180626202
# 3390   Personal Mailbox Access - Add/Remove  Q01437950-001   180626202
# ...                                     ...            ...         ...
# 34265  Personal Mailbox Access - Add/Remove  Q01547583-001   323159210
# 34432  Personal Mailbox Access - Add/Remove  Q01547571-001   323159210
# 35448  Personal Mailbox Access - Add/Remove  Q01556324-001   180626202
# 35843  Personal Mailbox Access - Add/Remove  Q01560977-001   180626202
# 36126  Personal Mailbox Access - Add/Remove  Q01555433-001   315467852
# 36230  Personal Mailbox Access - Add/Remove  Q01552740-001   315467852
# 36307  Personal Mailbox Access - Add/Remove  Q01552945-001   180626202
# 37329  Personal Mailbox Access - Add/Remove  Q01556028-001   296472020
# 37477  Personal Mailbox Access - Add/Remove  Q01558187-001   180626202
# 37505  Personal Mailbox Access - Add/Remove  Q01555894-001   535902738
# 37573  Personal Mailbox Access - Add/Remove  Q01556142-001   296472020
# 37905  Personal Mailbox Access - Add/Remove  Q01557720-001   180626202
# 38531  Personal Mailbox Access - Add/Remove  Q01562233-001   322888413
# 38606  Personal Mailbox Access - Add/Remove  Q01562436-001   322888413
# 38878  Personal Mailbox Access - Add/Remove  Q01563209-001   322888413
# 39017  Personal Mailbox Access - Add/Remove  Q01565259-001   322888413
# 39223  Personal Mailbox Access - Add/Remove  Q01564002-001   322888413
# 39486  Personal Mailbox Access - Add/Remove  Q01564871-001   322888413
# 39898  Personal Mailbox Access - Add/Remove  Q01565888-001   322888413
# 40080  Personal Mailbox Access - Add/Remove  Q01566200-001   322888413
# 40344  Personal Mailbox Access - Add/Remove  Q01567408-001   322888413
# 40562  Personal Mailbox Access - Add/Remove  Q01568070-001   322888413
# 41190  Personal Mailbox Access - Add/Remove  Q01570821-001   322888413
# 41806  Personal Mailbox Access - Add/Remove  Q01572412-001   322888413
# 41908  Personal Mailbox Access - Add/Remove  Q01572919-001   322888413
# 42441  Personal Mailbox Access - Add/Remove  Q01574841-001   322888413
# 42609  Personal Mailbox Access - Add/Remove  Q01575254-001   322888413
# 43080  Personal Mailbox Access - Add/Remove  Q01577147-001   322888413
# 43629  Personal Mailbox Access - Add/Remove  Q01578947-001   322888413
# 44188  Personal Mailbox Access - Add/Remove  Q01581208-001   190899732
#
#              Submit Date            Assigned_Dept_y         Close Date  \
# 59       2001/03/17 7:10  EAA_WINDOWS SERVICES_IMPL   2001/12/17 13:29
# 245    01/23/17 08:54:21  EAA_WINDOWS SERVICES_IMPL   2002/01/17 14:25
# 402     2001/03/17 12:27  EAA_WINDOWS SERVICES_IMPL    2002/07/17 8:44
# 432     2001/03/17 12:51  EAA_WINDOWS SERVICES_IMPL  01/13/17 14:33:01
# 517     2001/03/17 14:07  EAA_WINDOWS SERVICES_IMPL   2001/12/17 14:33
# 605     2001/03/17 15:25  EAA_WINDOWS SERVICES_IMPL   2001/12/17 15:43
# 798      2001/04/17 8:52  EAA_WINDOWS SERVICES_IMPL  01/17/17 07:48:42
# 871      2001/06/17 9:27  EAA_WINDOWS SERVICES_IMPL  01/20/17 11:06:01
# 1044   01/13/17 16:46:33  EAA_WINDOWS SERVICES_IMPL  01/23/17 14:39:05
# 1065    2001/04/17 11:19  EAA_WINDOWS SERVICES_IMPL  01/16/17 15:28:25
# 1111     2001/09/17 9:03  EAA_WINDOWS SERVICES_IMPL  01/20/17 09:10:07
# 1126   01/16/17 10:13:11  EAA_WINDOWS SERVICES_IMPL  01/26/17 10:14:09
# 1172    2001/04/17 12:56  EAA_WINDOWS SERVICES_IMPL  01/17/17 08:10:11
# 1309    2001/04/17 14:25  EAA_WINDOWS SERVICES_IMPL    2001/12/17 7:26
# 1310   01/16/17 16:48:18  EAA_WINDOWS SERVICES_IMPL  01/17/17 13:08:40
# 1311   01/20/17 11:15:29  EAA_WINDOWS SERVICES_IMPL  01/25/17 06:54:54
# 1384    2001/04/17 15:29  EAA_WINDOWS SERVICES_IMPL  01/17/17 08:47:55
# 1849     2001/09/17 7:16  EAA_WINDOWS SERVICES_IMPL  01/19/17 07:51:32
# 2121    2001/05/17 14:18  EAA_WINDOWS SERVICES_IMPL    2001/12/17 9:12
# 2142    2001/05/17 14:35  EAA_WINDOWS SERVICES_IMPL  01/16/17 12:49:57
# 2204    2001/05/17 16:35  EAA_WINDOWS SERVICES_IMPL  01/18/17 12:58:54
# 2302    2001/06/17 12:29  EAA_WINDOWS SERVICES_IMPL  01/13/17 09:49:18
# 2303    2001/05/17 17:30  EAA_WINDOWS SERVICES_IMPL   2002/08/17 12:01
# 2364     2001/06/17 7:32  EAA_WINDOWS SERVICES_IMPL   2001/11/17 15:37
# 2534    2001/06/17 10:58  EAA_WINDOWS SERVICES_IMPL  01/23/17 11:06:15
# 2563   01/16/17 11:30:32  EAA_WINDOWS SERVICES_IMPL  01/26/17 11:36:14
# 2766    2001/06/17 14:50  EAA_WINDOWS SERVICES_IMPL  01/18/17 14:58:35
# 2842    2001/06/17 16:10  EAA_WINDOWS SERVICES_IMPL  01/18/17 15:00:46
# 3082     2001/09/17 9:23  EAA_WINDOWS SERVICES_IMPL  01/19/17 07:53:00
# 3390    2001/09/17 12:17  EAA_WINDOWS SERVICES_IMPL  01/19/17 07:50:40
# ...                  ...                        ...                ...
# 34265   2003/06/17 11:38  EAA_WINDOWS SERVICES_IMPL  03/16/17 09:34:20
# 34432   2003/06/17 11:36  EAA_WINDOWS SERVICES_IMPL   2003/09/17 10:09
# 35448   2003/09/17 21:25  EAA_WINDOWS SERVICES_IMPL  03/17/17 07:40:45
# 35843   2003/11/17 17:39  EAA_WINDOWS SERVICES_IMPL  03/17/17 08:38:02
# 36126   2003/09/17 13:20  EAA_WINDOWS SERVICES_IMPL  03/20/17 09:58:06
# 36230   2003/08/17 11:35  EAA_WINDOWS SERVICES_IMPL  03/13/17 12:05:14
# 36307   2003/08/17 12:33  EAA_WINDOWS SERVICES_IMPL  03/14/17 07:45:34
# 37329   2003/09/17 16:08  EAA_WINDOWS SERVICES_IMPL  03/17/17 12:38:15
# 37477   2003/10/17 13:35  EAA_WINDOWS SERVICES_IMPL  03/17/17 07:38:12
# 37505   2003/09/17 15:27  EAA_WINDOWS SERVICES_IMPL  03/15/17 10:41:36
# 37573   2003/09/17 17:00  EAA_WINDOWS SERVICES_IMPL  03/17/17 12:52:07
# 37905   2003/10/17 11:32  EAA_WINDOWS SERVICES_IMPL  03/13/17 12:32:30
# 38531  03/13/17 09:06:32  EAA_WINDOWS SERVICES_IMPL  03/20/17 12:26:21
# 38606  03/13/17 10:10:52  EAA_WINDOWS SERVICES_IMPL  03/23/17 09:19:05
# 38878  03/13/17 13:18:38  EAA_WINDOWS SERVICES_IMPL  03/20/17 16:25:20
# 39017  03/14/17 11:29:37  EAA_WINDOWS SERVICES_IMPL  03/20/17 17:23:18
# 39223  03/13/17 17:08:43  EAA_WINDOWS SERVICES_IMPL  03/20/17 17:00:05
# 39486  03/14/17 09:53:56  EAA_WINDOWS SERVICES_IMPL  03/20/17 17:09:58
# 39898  03/14/17 14:15:53  EAA_WINDOWS SERVICES_IMPL  03/20/17 17:36:00
# 40080  03/14/17 15:55:27  EAA_WINDOWS SERVICES_IMPL  03/20/17 17:49:05
# 40344  03/15/17 09:19:47  EAA_WINDOWS SERVICES_IMPL  03/22/17 09:34:24
# 40562  03/15/17 12:10:24  EAA_WINDOWS SERVICES_IMPL  03/20/17 17:58:39
# 41190  03/16/17 14:42:27  EAA_WINDOWS SERVICES_IMPL  03/20/17 18:09:56
# 41806  03/17/17 11:25:44  EAA_WINDOWS SERVICES_IMPL  03/20/17 18:20:37
# 41908  03/17/17 14:19:51  EAA_WINDOWS SERVICES_IMPL  03/20/17 18:26:55
# 42441  03/20/17 11:17:40  EAA_WINDOWS SERVICES_IMPL  03/23/17 15:28:35
# 42609  03/20/17 12:39:38  EAA_WINDOWS SERVICES_IMPL  03/23/17 15:36:45
# 43080  03/21/17 09:59:22  EAA_WINDOWS SERVICES_IMPL  03/23/17 15:58:04
# 43629  03/21/17 21:40:47  EAA_WINDOWS SERVICES_IMPL  03/23/17 16:01:47
# 44188  03/22/17 15:56:02  EAA_WINDOWS SERVICES_IMPL  03/23/17 12:10:20
#
#                                      RBC_Line_Item_Title
# 59                  Personal Mailbox Access - Add/Remove
# 245                 Personal Mailbox Access - Add/Remove
# 402    2/3  ** See Updates ** 1/27  Personal Mailbox ...
# 432                 Personal Mailbox Access - Add/Remove
# 517                 Personal Mailbox Access - Add/Remove
# 605                 Personal Mailbox Access - Add/Remove
# 798                 Personal Mailbox Access - Add/Remove
# 871                 Personal Mailbox Access - Add/Remove
# 1044                Personal Mailbox Access - Add/Remove
# 1065                Personal Mailbox Access - Add/Remove
# 1111                Personal Mailbox Access - Add/Remove
# 1126                Personal Mailbox Access - Add/Remove
# 1172                Personal Mailbox Access - Add/Remove
# 1309           * ESC OOSLA -Please Merge AutoSab  record
# 1310   ** ESC - MERGE issue - Personal Mailbox Access...
# 1311   Jan 25 - just in case. Personal Mailbox Access...
# 1384                Personal Mailbox Access - Add/Remove
# 1849                Personal Mailbox Access - Add/Remove
# 2121        * ESC - Personal Mailbox Access - Add/Remove
# 2142   * ESC - Jan 11 - See updates - Personal Mailbo...
# 2204                Personal Mailbox Access - Add/Remove
# 2302   ** ESC  URGENT Personal Mailbox Access - Add/R...
# 2303   ESCALATION   ** ESC URGENT -Personal Mailbox A...
# 2364   * ESC - Jan 11 - See updates - Personal Mailbo...
# 2534   Remove all User Access    Personal Mailbox Acc...
# 2563                Personal Mailbox Access - Add/Remove
# 2766                Personal Mailbox Access - Add/Remove
# 2842                Personal Mailbox Access - Add/Remove
# 3082                Personal Mailbox Access - Add/Remove
# 3390                Personal Mailbox Access - Add/Remove
# ...                                                  ...
# 34265               Personal Mailbox Access - Add/Remove
# 34432  *ESC 03/09 - RUSH - Personal Mailbox Access - ...
# 35448               Personal Mailbox Access - Add/Remove
# 35843               Personal Mailbox Access - Add/Remove
# 36126              Temporary Mailbox Access - Add/Remove
# 36230               Personal Mailbox Access - Add/Remove
# 36307               Personal Mailbox Access - Add/Remove
# 37329               Personal Mailbox Access - Add/Remove
# 37477      03/22 PA Personal Mailbox Access - Add/Remove
# 37505  * ESC - Mar 14 - see updates - Personal Mailbo...
# 37573               Personal Mailbox Access - Add/Remove
# 37905  *ESC 03/13 - RUSH - Personal Mailbox Access - ...
# 38531               Personal Mailbox Access - Add/Remove
# 38606  03/20 - PT - Personal Mailbox Access - Add/Remove
# 38878  *ESC 03/20 - RUSH- Personal Mailbox Access - A...
# 39017               Personal Mailbox Access - Add/Remove
# 39223               Personal Mailbox Access - Add/Remove
# 39486               Personal Mailbox Access - Add/Remove
# 39898               Personal Mailbox Access - Add/Remove
# 40080               Personal Mailbox Access - Add/Remove
# 40344  03/20 - PT -*ESC See Updates - Personal Mailbo...
# 40562               Personal Mailbox Access - Add/Remove
# 41190               Personal Mailbox Access - Add/Remove
# 41806               Personal Mailbox Access - Add/Remove
# 41908               Personal Mailbox Access - Add/Remove
# 42441               Personal Mailbox Access - Add/Remove
# 42609               Personal Mailbox Access - Add/Remove
# 43080               Personal Mailbox Access - Add/Remove
# 43629               Personal Mailbox Access - Add/Remove
# 44188    *ESC* RUSH Personal Mailbox Access - Add/Remove
#
# [219 rows x 9 columns]
