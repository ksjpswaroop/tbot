# %% [markdown]
# # Pre-Processing Data to make to ready for analysis

# %%
import numpy as np
import pandas as pd
import os , sys , glob

# %%
# The environmet variable should be set at a system level rather than in code. Setting it now, as python is not picking it up. 
os.environ['DSX_PROJECT_DIR'] = "C:\\Project\\Data\\raw"

#os.listdir(os.environ['DSX_PROJECT_DIR'])
#print(os.environ['DSX_PROJECT_DIR'])

#os.listdir("C:\Project\Data\raw\".join("sm9\apps\**"))

#os.listdir(os.environ['DSX_PROJECT_DIR'])
#pd.read_excel(os.environ['DSX_PROJECT_DIR'] + '/sm9/windows/')

# Getting the list of file in the directory

apps_files = glob.glob(os.environ['DSX_PROJECT_DIR'] +  "\\sm9\\apps\\*.csv")
#apps_files

# %%
#os.environ.items()
# To-Do : Preferbly specify type of the columns you care about. Performing aggregation ops like sum , avg , grouping are 
# expensive with objects by faster with primitive types like int, float. 

# Check the time taken for append versus concat. Seems to me that append is slower than concat.

# rename columns to not have spaces in them. 

apps_data = pd.DataFrame()
for app_file in apps_files:
    df = pd.read_csv(app_file , encoding='latin-1')
    #apps_data = pd.concat([apps_data,df])
    apps_data = apps_data.append(df,ignore_index=True)
apps_data
# assigned_to = apps_data['Assigned to'].groupby(level=0)
# assigned_to.count()

#apps_data.groupby('Assigned to').size()
#assigned_to
# Out:
# C:\Users\581686284\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
#                         Assigned Dept Assigned to         Close Date  \
# 0       EAA_APPLICATION SERVICES_IMPL   535506877   2004/02/18 11:47
# 1       EAA_APPLICATION SERVICES_IMPL   310294822   2004/02/18 13:54
# 2       EAA_APPLICATION SERVICES_IMPL   631444387  04/16/18 10:37:01
# 3       EAA_APPLICATION SERVICES_IMPL   180190019  04/17/18 09:58:56
# 4       EAA_APPLICATION SERVICES_IMPL   324653500   2004/02/18 19:37
# 5       EAA_APPLICATION SERVICES_IMPL   191458827  04/23/18 17:38:20
# 6       EAA_APPLICATION SERVICES_IMPL   180190019   2004/02/18 15:27
# ...

# %%
apps_data.columns
# Out:
# Index(['Assigned Dept', 'Assigned to', 'Close Date', 'Number',
#        'RBC Line Item Title', 'RBCMMPRITM', 'Rbc Description', 'Received Date',
#        'Submit Date', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 9'],
#       dtype='object')

# %%
#apps_data['Unnamed: 10'].unique().tolist()
#unnamed_10 = apps_data.groupby('Unnamed: 10')

#unnamed_10 = apps_data.groupby('Unnamed: 10')
#unnamed_10

apps_data['Assigned Dept'].value_counts()

apps_data = apps_data.loc[apps_data['Assigned Dept'] == 'EAA_APPLICATION SERVICES_IMPL']

apps_data

#apps_data['Assigned to'].unique().tolist()



# apps_assigned_data['Assigned to'].value_counts()

# apps_assigned_data[apps_assigned_data['Assigned to']=='698544350.0']

#apps_assigned_data.dtypes

#apps_assigned_data['Assigned to'] = apps_assigned_data['Assigned to'].astype(int)

#apps_assigned_data[apps_assigned_data['Assigned to'].str.contains(".0")]

#apps_assigned_data['Assigned to'].str.replace('.0','')

#apps_assigned_data['Assigned to'].value_counts()

#apps_assigned_data.loc[apps_assigned_data['Assigned to'] in '.0']

#apps_data.loc[apps_assigned_data['Assigned to'] = apps_assigned_data['Assigned to'].replace('.0','')]

#apps_data.loc[apps_assigned_data['Assigned to'].str.replace('.0','')]




#apps_assigned_data['Assigned to'].astype(str)

#apps_assigned_data['Assigned to'] = apps_assigned_data['Assigned to'].astype(str)

#apps_assigned_data.info()

#apps_assigned_Remove_Dot_Zero_data

#apps_assigned_Remove_Dot_Zero_data.value_counts()

#apps_assigned_data.info()
#apps_assigned_data['Assigned to'].value_counts()

# CLEANING : 698544350.0 TO 698544350 SO REMOVE .0 WHEREEVER IT IS

#apps_data.loc[apps_data['Assigned Dept'] == 'physically the iSeries/Milvus system is in Toronto. - comp_permission - MLV:ERMA::ENQUIRY']

#apps_data.loc[apps_data['Assigned Dept'].str.match('physically the iSeries/Milvus system is in Toronto. - comp_permission - MLV:ERMA::ENQUIRY')]

# cat_items = sn_data.groupby('cat_item')
# cat_items['cat_item']
# Out:
#                         Assigned Dept Assigned to         Close Date  \
# 0       EAA_APPLICATION SERVICES_IMPL   535506877   2004/02/18 11:47
# 1       EAA_APPLICATION SERVICES_IMPL   310294822   2004/02/18 13:54
# 2       EAA_APPLICATION SERVICES_IMPL   631444387  04/16/18 10:37:01
# 3       EAA_APPLICATION SERVICES_IMPL   180190019  04/17/18 09:58:56
# 4       EAA_APPLICATION SERVICES_IMPL   324653500   2004/02/18 19:37
# 5       EAA_APPLICATION SERVICES_IMPL   191458827  04/23/18 17:38:20
# 6       EAA_APPLICATION SERVICES_IMPL   180190019   2004/02/18 15:27
# 7       EAA_APPLICATION SERVICES_IMPL   310294822   2004/05/18 18:36
# 8       EAA_APPLICATION SERVICES_IMPL   180190019    2004/03/18 9:34
# 9       EAA_APPLICATION SERVICES_IMPL   180190019    2004/03/18 9:36
# 10      EAA_APPLICATION SERVICES_IMPL   180190019    2004/03/18 9:49
# 11      EAA_APPLICATION SERVICES_IMPL   318215316    2004/05/18 9:10
# 12      EAA_APPLICATION SERVICES_IMPL   310294822  04/13/18 13:36:03
# ...

# %%
#apps_assigned_data = apps_data.dropna(subset=['Assigned to'])

analyst_ids = apps_data['Assigned to'].unique().tolist()

analyst_ids
# Out:
# ['535506877',
#  '310294822',
#  '631444387',
#  '180190019',
#  '324653500',
#  '191458827',
#  '318215316',
#  '328453238',
#  '195808886',
#  nan,
#  '698544350',
#  '329808695',
#  '787489756',
#  '776883118',
#  '328874185',
#  '319749875',
#  '522079805',
#  '936531946',
#  '312363658',
#  '956519110',
#  '544269145',
#  '291180362',
#  '191918473',
#  '648708485',
#  '327004545',
#  '850772930',
#  '69854350',
#  '521307710',
#  '829617786',
#  '178412342',
#  '543589881',
#  '698554350',
#  '190899732',
#  '318687647',
#  '296472020',
#  '311744627',
#  '317597441',
#  '319463568',
#  '315073148',
#  '816948798',
#  '105453799',
#  '319574810',
#  '318801727',
#  '180626202',
#  '856836887',
#  '322930777',
#  '543598601',
#  '322853433',
#  '323159210',
#  '322888413',
#  '534728654',
#  '315467852',
#  '753392992',
#  '631444398',
#  '6985443350',
#  '859929358',
#  '528435936',
#  '322143223',
#  '859929192',
#  318215316.0,
#  776883118.0,
#  105453799.0,
#  856836887.0,
# ...

# %%
def object_to_int(x):
    try:
        return round(int(x))
    except ValueError:
        return None
    
#apps_data['Assigned to'].apply(test_apply).dropna().unique().tolist()


apps_data['Assigned to'] = apps_data['Assigned to'].apply(object_to_int)
#apps_data['Assigned to'] = apps_data['Assigned to'].dropna(inplace= True)

apps_data = apps_data[pd.notnull(apps_data['Assigned to'])]

apps_data['Assigned to'].unique().tolist()
# Out:
# C:\Users\581686284\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# [535506877,
#  310294822,
#  631444387,
#  180190019,
#  324653500,
#  191458827,
#  318215316,
#  328453238,
#  195808886,
#  698544350,
#  329808695,
#  787489756,
#  776883118,
#  328874185,
#  319749875,
#  522079805,
#  936531946,
#  312363658,
#  956519110,
#  544269145,
#  291180362,
#  191918473,
#  648708485,
#  327004545,
#  850772930,
#  69854350,
#  521307710,
#  829617786,
#  178412342,
#  543589881,
#  698554350,
#  190899732,
#  318687647,
#  296472020,
#  311744627,
#  317597441,
#  319463568,
#  315073148,
#  816948798,
#  105453799,
# ...

# %%
#apps_data.loc[apps_data['Assigned to'] == 6985444350.0]

# %%
#apps_data['Assigned to'] = apps_data['Assigned to'].astype(int). Need to find a value to remove -ve value in Assigned to. The 
# -ve value is introduced as we a number beyond the max int value '6985444350.0', which get converted to a -ve value. there is 
# just one ticket resolved by this analyst way back in 2017. So, its not relevant for us. Analyst id, is likely a typo. 
# Best ignored. However, need to remove -ve value 

apps_data['Assigned to'] = pd.to_numeric(apps_data['Assigned to'])

# apps_data['Assigned to'].unique().tolist()

# The below line confirms we can remove column 'Unnamed: 10', as it only contains null values. 

# pd.notnull(apps_data['Unnamed: 10']).unique().tolist()

# # The below line confirms we can remove column 'Unnamed: 10', as it only contains null values. 

# pd.notnull(apps_data['Unnamed: 11']).unique().tolist()

# pd.notnull(apps_data['Unnamed: 12']).unique().tolist()

# pd.notnull(apps_data['Unnamed: 13']).unique().tolist()

# pd.notnull(apps_data['Unnamed: 14']).unique().tolist()

# pd.notnull(apps_data['Unnamed: 15']).unique().tolist()

# pd.notnull(apps_data['Unnamed: 16']).unique().tolist()


apps_data.dropna(axis=1, how='all' , inplace=True)

apps_data.info()

#pd.notnull(apps_data['Unnamed: 12']).unique().tolist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104605 entries, 0 to 128077
# Data columns (total 8 columns):
# Assigned Dept          104605 non-null object
# Assigned to            104605 non-null int64
# Close Date             104605 non-null object
# Number                 104605 non-null object
# RBC Line Item Title    104601 non-null object
# RBCMMPRITM             78971 non-null object
# Rbc Description        104603 non-null object
# Submit Date            104605 non-null object
# dtypes: int64(1), object(7)
# memory usage: 7.2+ MB

# %%
# Lets find list of unique RBC Line Item Titles. Whether they are consistent or need pre-processing. 

apps_data['RBC Line Item Title'].unique().tolist()
# Out:
# ['A termination request has recently been submitted on behalf of RBC Access Manager for Sato, Misako -',
#  'A termination request has recently been submitted on behalf of RBC Access Manager for Navarro, Kevin',
#  '04/14 - RBCIS term Frédéric ERBETTI - 523335040',
#  '04/15 PD  RBCIS - BEDFORD - EXIT Arnaud COURTOIS  April 15  NO UK apps',
#  'ESAM HR TERMINATION - SM9',
#  'Cards & Payments Audit Bulk Request - Generic Bulk',
#  '04/01 PD  RBCIS - BEDFORD  Termination - EXIT G. FERERRA - Primary Control mail 1',
#  'An access review has recently been completed by Legge, Shelly - 816077168                           ',
#  '04/01 PD RBCIS - BEDFORD Termination - EXIT G. MALINVERNI - Primary Control mail 1  Apr 1',
#  '04/01 PD  RBCIS - BEDFORD Termination - EXIT Noel FERNANDEZ PUGA - Primary Control mail 1 Apr 1 no UK apps',
#  '04/01 PD  RBCIS - Bedford - Termination EXIT Guilhem FRAJ - Primary Control mail 1  Apr 1 - no UK apps',
#  '04/09 - PC ISERIES USER ENROLMENT REQUEST',
# ...

# %%
# Getting a list of unique line items from Service Now excel

import numpy as np
import pandas as pd

df = pd.read_csv("C:\\Project\\Data\\ServiceNow_data.csv" , encoding = "Latin-1")
df['cat_item'].unique().tolist()
# Out:
# ['Modify Domain Group - Owner Change',
#  'Distribution List - Add/Remove Members',
#  'Application - Password Reset/Unlock',
#  'Add Users to Generic Mailbox',
#  'Add User to Group',
#  'Retrieve Domain Group Information',
#  'UNIX Password Change',
#  'Trust Accounting',
#  'Create Application Group',
#  'Existing Network Folder/Shared Drive \x96 Add/Remove',
#  'T24',
#  'Create VPN Access',
#  'IA Code/Branch Access Add/Remove',
#  'Morningstar / Advisor Workstation (AWS)',
#  'myMarketPlace Help - Escalation / Cancellation',
#  'PeopleSoft GL Financials',
#  'UNIX Create User NetGroup',
#  'Modify Service ID - Add to Group',
#  'RightFax ID',
#  'New Shared Mailbox/Calendar',
#  'Thomson One',
#  'Rep Code Access',
#  'Broadridge - Trade Limits',
#  'Private Client Group (PCG) - Job Template',
#  'Remove Multiple Users from Group',
#  'Remove all User Access',
#  'UNIX User NetGroup Access to Servers',
#  'User Logon ID and Personal Mailbox',
#  'Tellerphone',
# ...

# %%
import numpy as np
import pandas as pd 

os.environ['DSX_PROJECT_DIR'] = "C:\\Project\\Data\\raw"
windows_files = glob.glob(os.environ['DSX_PROJECT_DIR'] +  "\\sm9\\windows\\*.csv")

windows_data = pd.DataFrame()
for windows_file in windows_files:
    df = pd.read_csv(windows_file , encoding='latin-1')
    #windows_data = pd.concat([windows_data,df])
    windows_data = windows_data.append(df,ignore_index=True)
windows_data
# Out:
# C:\Users\581686284\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
#                     Assigned Dept Assigned to         Close Date  \
# 0       EAA_WINDOWS SERVICES_IMPL         NaN  04/21/17 03:10:36
# 1       EAA_WINDOWS SERVICES_IMPL   956519110    2004/03/17 7:38
# 2       EAA_WINDOWS SERVICES_IMPL         NaN  04/26/17 03:07:50
# 3       EAA_WINDOWS SERVICES_IMPL         NaN  04/26/17 03:07:55
# 4       EAA_WINDOWS SERVICES_IMPL         NaN  04/26/17 03:08:00
# 5       EAA_WINDOWS SERVICES_IMPL         NaN  04/26/17 03:08:04
# 6       EAA_WINDOWS SERVICES_IMPL   315467852   2004/05/17 11:11
# 7       EAA_WINDOWS SERVICES_IMPL         NaN  04/26/17 03:08:08
# ...

# %%
windows_data = windows_data.loc[windows_data['Assigned Dept'] == 'EAA_WINDOWS SERVICES_IMPL']

# Converts objects to int (upcasted to float) & set None for those that can't be converted (NaN , Internal)
windows_data['Assigned to'] = windows_data['Assigned to'].apply(object_to_int)

# Remove those tickets that don't have Analyst linked to it. Noise. 
windows_data = windows_data[pd.notnull(windows_data['Assigned to'])]

# Convert from float to int. All tickets that are assigned are now ints. Int are faster to process , is primitive, so takes 
# less memory

windows_data['Assigned to'] = pd.to_numeric(windows_data['Assigned to'])

# Drop all columns having only NaN values (All unamed columns are filtered out)

windows_data.dropna(axis=1, how='all' , inplace=True)

windows_data
# Out:
#                     Assigned Dept  Assigned to         Close Date  \
# 1       EAA_WINDOWS SERVICES_IMPL    956519110    2004/03/17 7:38
# 6       EAA_WINDOWS SERVICES_IMPL    315467852   2004/05/17 11:11
# 8       EAA_WINDOWS SERVICES_IMPL    936531946   2004/04/17 12:32
# 9       EAA_WINDOWS SERVICES_IMPL    631444387    2004/07/17 9:11
# 10      EAA_WINDOWS SERVICES_IMPL    631444387   2004/06/17 11:15
# 11      EAA_WINDOWS SERVICES_IMPL    631444387   2004/06/17 11:16
# 12      EAA_WINDOWS SERVICES_IMPL    522079805   2004/03/17 13:09
# 13      EAA_WINDOWS SERVICES_IMPL    180190019    2004/03/17 8:39
# 14      EAA_WINDOWS SERVICES_IMPL    180190019    2004/03/17 8:39
# 15      EAA_WINDOWS SERVICES_IMPL    956519110   2004/04/17 12:20
# 18      EAA_WINDOWS SERVICES_IMPL    180626202    2004/12/17 7:09
# 19      EAA_WINDOWS SERVICES_IMPL    180626202    2004/12/17 7:09
# 20      EAA_WINDOWS SERVICES_IMPL    191918473  04/13/17 13:50:02
# ...

# %%
windows_data.head()
# Out:
#                 Assigned Dept  Assigned to        Close Date         Number  \
# 1   EAA_WINDOWS SERVICES_IMPL  956519110.0   2004/03/17 7:38  Q01482939-001
# 6   EAA_WINDOWS SERVICES_IMPL  315467852.0  2004/05/17 11:11  Q01525233-001
# 8   EAA_WINDOWS SERVICES_IMPL  936531946.0  2004/04/17 12:32  Q01528761-001
# 9   EAA_WINDOWS SERVICES_IMPL  631444387.0   2004/07/17 9:11  Q01529272-001
# 10  EAA_WINDOWS SERVICES_IMPL  631444387.0  2004/06/17 11:15  Q00975425-003
#
#                                   RBC Line Item Title   RBCMMPRITM  \
# 1   04/02 - PD - RBCIS - BEDFORD - termination - F...          NaN
# 6   3/4/17 - PD - EOD Grant Temporary Mailbox Acce...  RITM0607195
# 8   04/04 - PD - revoke AGX and H drive. Remove al...  RITM0612543
# 9                 04/07 - PD - Remove all User Access  RITM0613254
# 10  03/?? - PO - RBCIS - BEDFORD - FAS/CAB Manager...          NaN
#
#                                       Rbc Description        Submit Date
# ...

# %%
apps_data.head()
# Out:
#                    Assigned Dept  Assigned to         Close Date  \
# 0  EAA_APPLICATION SERVICES_IMPL    535506877   2004/02/18 11:47
# 1  EAA_APPLICATION SERVICES_IMPL    310294822   2004/02/18 13:54
# 2  EAA_APPLICATION SERVICES_IMPL    631444387  04/16/18 10:37:01
# 3  EAA_APPLICATION SERVICES_IMPL    180190019  04/17/18 09:58:56
# 4  EAA_APPLICATION SERVICES_IMPL    324653500   2004/02/18 19:37
#
#           Number                                RBC Line Item Title  \
# 0  Q01654864-001  A termination request has recently been submit...
# 1  Q01655290-001  A termination request has recently been submit...
# 2  Q02211785-001    04/14 - RBCIS term Frédéric ERBETTI - 523335040
# 3  Q02244759-001  04/15 PD  RBCIS - BEDFORD - EXIT Arnaud COURTO...
# 4  Q02264742-001                          ESAM HR TERMINATION - SM9
#
#   RBCMMPRITM                                    Rbc Description  \
# 0        NaN  A termination request has recently been submit...
# ...

# %%
pd.DataFrame(np.random.randn(10,3))  

df.iloc[::2,0] = np.nan; df.iloc[::4,1] = np.nan; df.iloc[::3,2] = np.nan;
# Out:
#           0         1         2
# 0 -0.202634 -0.707664  0.418725
# 1  1.858979 -0.558331 -1.636738
# 2  1.798220 -0.579127 -0.200257
# 3  0.090411  0.842965  0.908785
# 4  1.060811  1.211391 -0.583689
# 5 -0.778319  2.334214 -0.466045
# 6  0.049118 -0.871827 -0.273076
# 7 -0.413483  1.256312  0.112715
# 8  0.379706 -2.298145  0.929413
# 9  0.336612 -0.600112 -0.633457

# %%
import numpy as np
import pandas as pd 

df = pd.read_csv("C:\\Users\\581686284\\Downloads\\phone_data.csv")
df.head(7)
# Out:
#    index            date  duration  item    month   network network_type
# 0      0  15/10/14 06:58    34.429  data  2014-11      data         data
# 1      1  15/10/14 06:58    13.000  call  2014-11  Vodafone       mobile
# 2      2  15/10/14 14:46    23.000  call  2014-11    Meteor       mobile
# 3      3  15/10/14 14:48     4.000  call  2014-11     Tesco       mobile
# 4      4  15/10/14 17:27     4.000  call  2014-11     Tesco       mobile
# 5      5  15/10/14 18:55     4.000  call  2014-11     Tesco       mobile
# 6      6  16/10/14 06:58    34.429  data  2014-11      data         data

# %%
groupby_month = df.groupby(['month','item'])
groupby_month.groups.keys()
# Out:
# dict_keys([('2014-11', 'call'), ('2014-11', 'data'), ('2014-11', 'sms'), ('2014-12', 'call'), ('2014-12', 'data'), ('2014-12', 'sms'), ('2015-01', 'call'), ('2015-01', 'data'), ('2015-01', 'sms'), ('2015-02', 'call'), ('2015-02', 'data'), ('2015-02', 'sms'), ('2015-03', 'call'), ('2015-03', 'data'), ('2015-03', 'sms')])

# %%
# for index in groupby_month.groups[('2014-11', 'data')]:
#     print(index)

groupby_month.groups[('2014-11', 'data')]
# Out:
# Int64Index([  0,   6,  13,  26,  39,  45,  54,  56,  58,  66,  80,  81,  87,
#              92,  95,  97, 101, 111, 114, 120, 131, 151, 159, 170, 182, 189,
#             192, 199, 208],
#            dtype='int64')

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\581686284\\Downloads\\netflix.csv')
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# title                1000 non-null object
# rating               1000 non-null object
# ratingLevel          941 non-null object
# ratingDescription    1000 non-null int64
# release year         1000 non-null int64
# user rating score    605 non-null float64
# user rating size     1000 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 574 entries, 0 to 995
# Data columns (total 7 columns):
# title                574 non-null object
# rating               574 non-null object
# ratingLevel          574 non-null object
# ratingDescription    574 non-null int64
# release year         574 non-null int64
# user rating score    574 non-null float64
# user rating size     574 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 35.9+ KB

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 246 entries, 0 to 979
# Data columns (total 7 columns):
# title                246 non-null object
# rating               246 non-null object
# ratingLevel          246 non-null object
# ratingDescription    246 non-null int64
# release year         246 non-null int64
# user rating score    246 non-null float64
# user rating size     246 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 15.4+ KB

# %%
df_grouped = df.groupby('release year')['.groups.keys()']
df_grouped
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-2672a3278813> in <module>()
# ----> 1 df_grouped = df.groupby('release year')['1940']
#       2 df_grouped
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     265         else:
#     266             if key not in self.obj:
# --> 267                 raise KeyError("Column not found: {key}".format(key=key))
#     268             return self._gotitem(key, ndim=1)
#     269
#
# KeyError: 'Column not found: 1940'

# %%
dates = pd.date_range('1/1/2000', periods=13)
dates
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\tseries\frequencies.py in to_offset(freq)
#     153                 # the last element must be blank
# --> 154                 raise ValueError('last element must be blank')
#     155             for sep, stride, name in zip(splitted[0::4], splitted[1::4],
#
# ValueError: last element must be blank
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-f101d3aac029> in <module>()
# ----> 1 dates = pd.date_range('1/1/2000', periods=13,  freq="2")
#       2 dates
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\indexes\datetimes.py in date_range(start, end, periods, freq, tz, normalize, name, closed, **kwargs)
# ...
